# %% [markdown]
# # 🚌 대구버스 공공데이터 API 실습 워크시트
#
# **목표:** 공공데이터포털 API 문서를 읽고, 직접 데이터를 불러와봅니다.
#
# ---
# ## ✅ 시작 전 체크리스트
# - [ ] 공공데이터포털 회원가입 완료
# - [ ] 대구버스정보시스템 API 활용 신청 완료
# - [ ] API 키 승인 완료 (마이페이지 > 활용신청 현황에서 확인)
#
# > 📌 API 페이지 주소: https://www.data.go.kr/data/15139134/openapi.do

# %% [markdown]
# ---
# ## 📖 Step 0. API가 뭔가요?
#
# **API(Application Programming Interface)** 는 프로그램끼리 데이터를 주고받는 약속된 방법입니다.
#
# ```
# 🙋 나(파이썬 코드)
#       ↓ requests.get() 으로 요청
# 🏢 공공데이터 서버
#       ↓ JSON 데이터로 응답
# 📦 데이터 수신!
# ```
#
# ### 응답 코드 의미
# | 코드 | 의미 |
# |------|------|
# | **200** | ✅ 성공! |
# | **401** | 🔴 API 키 오류 |
# | **400** | 🔴 파라미터 오류 |
# | **500** | 🔴 서버 오류 |

# %% [markdown]
# ---
# ## 🔑 Step 1. API 키 설정
#
# 공공데이터포털 마이페이지에서 발급받은 **일반 인증키(Decoding)** 를 입력하세요.
#
# > ⚠️ 주의: 키 앞뒤에 공백이나 탭이 들어가면 401 오류가 납니다! `.strip()` 필수!

# %%
# 비동기(async) 허용 
# --> jupyter notebook에서 이미 허용
# --> 라이브러리 실행 또는 다양한 상황에서 vs code가 또 허용
# --> 이미 돌고 있는 또 돌아라 --> 중첩 (멘붕) --> 허용
import nest_asyncio
nest_asyncio.apply()

# %%
import os
from dotenv import load_dotenv

load_dotenv()

API_KEY = os.getenv('OPENAPI_API_KEY')

# %%
import requests
import json

print("API 키 길이:", len(API_KEY))
print("앞 10자리:", API_KEY[:10], "...")
# Out:
# API 키 길이: 64
# 앞 10자리: 99c2b74393 ...

# %% [markdown]
# ---
# ## 📡 Step 2. API 문서 읽기 연습
#
# 아래 사이트에서 **getBasic02** 항목을 찾아 다음을 채워보세요.
#
# 🌐 https://www.data.go.kr/data/15139134/openapi.do
#
# ### 📝 탐색 미션 (빈칸 채우기)
#
# ```
# 1. API 이름: getBasic02
# 2. 기능 설명: 노선, 정류장, 노드, 링크를 제공받는 서비스
# 3. 필수 파라미터(*): serviceKey
# 4. 응답 데이터에 포함된 항목들:
#    - route (노선): routeId, routeNo, dataconnareacd	string
# 데이터연계지역
#
# routeId	string
# 노선 ID
#
# routeNo	string
# 노선 번호
#
# stBsId	string
# 시점 정류소 ID
#
# edBsId	string
# 종점 정류소 ID
#
# stNm	string
# 시점명
#
# edNm	string
# 종점명
#
# routeNote	string
# 노선설명
#
# dirRouteNote	string
# 정방향 노선설명
#
# ndirRouteNote	string
# 역방향 노선설명
#
# routeTCd	string
# 노선타입(1:급행, 2:순환, 3:간선, 4:지선, 5:맞춤, 6:마을버스, G or 91:경산, C or 92:칠곡, Y or 93:영천)
#    - bs (정류장): bsId, bsNm(정류장 이름), wincId(모바일ID), xPos(x좌표), yPos(y좌표)
#    - node (노드): nodeId, nodeNm, bsYn(정류장인지 구분하는 파라미터), xPos(x좌표), yPos(y좌표)
# ```

# %% [markdown]
# ```python
# print('Hello, world')
# ```

# %% [markdown]
# ---
# ## 🚀 Step 3. getBasic02 호출하기 (전체 기초 데이터)

# %%
# 📡 API 주소
url = "https://apis.data.go.kr/6270000/dbmsapi02/getBasic02"

# 📋 요청 파라미터
params = {
    "serviceKey": API_KEY
}

# 🚀 요청 보내기
response = requests.get(url, params=params)

# ✅ 결과 확인
print("응답 코드:", response.status_code)

if response.status_code == 200:
    print("✅ 성공!")
elif response.status_code == 401:
    print("🔴 API 키를 확인하세요!")
else:
    print("🔴 오류:", response.status_code)
# Out:
# 응답 코드: 200
# ✅ 성공!

# %% [markdown]
# ---
# ## 🔍 Step 4. 응답 데이터 구조 탐색

# %%
# JSON으로 변환
data = response.json()

# 전체 키 확인
# print(data)
# print('=' * 50)
print("최상위 키:", list(data.keys()))
# Out:
# 최상위 키: ['header', 'body']

# %%
# 헤더 확인 (성공 여부)
header = data["header"]
print("성공 여부:", header["success"])
print("결과 메시지:", header["resultMsg"])
print("결과 코드:", header["resultCode"])
# Out:
# 성공 여부: True
# 결과 메시지: 성공
# 결과 코드: 0000

# %%
# 바디 확인 (실제 데이터)
body = data["body"]
print("총 데이터 수:", body["totalCount"])
print("items 키 목록:", list(body["items"].keys()))
# Out:
# 총 데이터 수: 25172
# items 키 목록: ['bs', 'node', 'route', 'link']

# %% [markdown]
# ---
# ## 🚌 Step 5. 노선 정보 꺼내기

# %%
# 노선 데이터
routes = data["body"]["items"]["route"]

print(f"전체 노선 수: {len(routes)}개")
print("\n첫 번째 노선 정보:")
print(json.dumps(routes[0], ensure_ascii=False, indent=2))
# Out:
# 전체 노선 수: 522개
#
# 첫 번째 노선 정보:
# {
#   "routeId": "4050003000",
#   "routeNo": "동구3",
#   "routeNote": "부동방면",
#   "routeTCd": "4",
#   "stBsId": "7021051300",
#   "edBsId": "7011030000",
#   "stNm": "칠성시장",
#   "edNm": "부동",
#   "dirRouteNote": "부동",
#   "ndirRouteNote": "칠성시장",
#   "dataconnareacd": "DG"
# }

# %%
# 노선 번호만 출력 (앞 10개)
print("노선 번호 목록 (앞 10개):")
for route in routes[:10]:
    print(f"  - {route['routeNo']} ({route['stNm']} → {route['edNm']})")
# Out:
# 노선 번호 목록 (앞 10개):
#   - 동구3 (칠성시장 → 부동)
#   - 504 (방천리 → 두리봉터널)
#   - 232-1 (방천리 → 방천리)
#   - 403 (범물동 → 조야동)
#   - 405 (삼산리 → 방천리)
#   - 413 (대일리 → 종합유통단지)
#   - 503 (연경동 → 성서산업단지)
#   - 706 (관음동 → 대곡지구)
#   - 708 (동호동(북구) → 동호지구)
#   - 719 (관음동 → 금구리)

# %% [markdown]
# ### 🎯 미션 1
# 아래 코드를 완성해서 **급행** 노선만 출력해보세요!

# %%
# 🎯 미션 1: 급행 노선만 찾기
print("급행 노선 목록:")
for route in routes:
    if "급행" in route["routeNo"]:   # ← 이 조건을 바꿔보세요!
        print(f"  🚌 {route['routeNo']} | {route['stNm']} → {route['edNm']}")
# Out:
# 급행 노선 목록:
#   🚌 급행8 | 달성2차산업단지 → 서대구역
#   🚌 급행8-1 | 유곡리 → 진천역
#   🚌 급행9 | 동호동 → 군위군청
#   🚌 급행9-2 | 동호동 → 삼국유사면문화관
#   🚌 급행2 | 냉천리 → 동호동(북구)
#   🚌 급행10 | 대천동 → 반야월역
#   🚌 급행9-3 | 동호동 → 소보시장
#   🚌 급행9-1 | 동호동 → 우보정류장
#   🚌 급행5 | 성서산업단지 → 대구대
#   🚌 급행7 | 대곡동(공영차고지) → 동호동
#   🚌 급행1 | 동화사 → 동대구역
#   🚌 급행1 | 동화사 → 매곡
#   🚌 급행3 | 범물동 → 동명면

# %%
routes
# Out:
# [{'routeId': '4050003000',
#   'routeNo': '동구3',
#   'routeNote': '부동방면',
#   'routeTCd': '4',
#   'stBsId': '7021051300',
#   'edBsId': '7011030000',
#   'stNm': '칠성시장',
#   'edNm': '부동',
#   'dirRouteNote': '부동',
#   'ndirRouteNote': '칠성시장',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000504000',
#   'routeNo': '504',
#   'routeTCd': '3',
#   'stBsId': '7111069100',
#   'edBsId': '7061033500',
#   'stNm': '방천리',
#   'edNm': '두리봉터널',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000323101',
#   'routeNo': '232-1',
#   'routeTCd': '3',
#   'stBsId': '7111069100',
#   'edBsId': '7111069100',
#   'stNm': '방천리',
#   'edNm': '방천리',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000403001',
#   'routeNo': '403',
#   'routeTCd': '3',
#   'stBsId': '7061021400',
#   'edBsId': '7021029800',
#   'stNm': '범물동',
#   'edNm': '조야동',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000405004',
#   'routeNo': '405',
#   'routeTCd': '3',
#   'stBsId': '7111081701',
#   'edBsId': '7111069100',
#   'stNm': '삼산리',
#   'edNm': '방천리',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000413001',
#   'routeNo': '413',
#   'routeTCd': '3',
#   'stBsId': '7111045900',
#   'edBsId': '7021047100',
#   'stNm': '대일리',
#   'edNm': '종합유통단지',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000503001',
#   'routeNo': '503',
#   'routeTCd': '3',
#   'stBsId': '7021064600',
#   'edBsId': '7041054300',
#   'stNm': '연경동',
#   'edNm': '성서산업단지',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000706001',
#   'routeNo': '706',
#   'routeTCd': '3',
#   'stBsId': '7021001400',
#   'edBsId': '7041020700',
#   'stNm': '관음동',
#   'edNm': '대곡지구',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000708002',
#   'routeNo': '708',
#   'routeTCd': '3',
#   'stBsId': '7021062000',
#   'edBsId': '7011067600',
#   'stNm': '동호동(북구)',
#   'edNm': '동호지구',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000719001',
#   'routeNo': '719',
#   'routeTCd': '3',
#   'stBsId': '7021041700',
#   'edBsId': '7121020700',
#   'stNm': '관음동',
#   'edNm': '금구리',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000730002',
#   'routeNo': '730',
#   'routeTCd': '3',
#   'stBsId': '3690005830',
#   'edBsId': '7051009200',
#   'stNm': '동명면',
#   'edNm': '대덕맨션',
#   'dirRouteNote': '삼정골',
#   'ndirRouteNote': '칠곡',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000802000',
#   'routeNo': '802',
#   'routeTCd': '3',
#   'stBsId': '7121021100',
#   'edBsId': '7031021600',
#   'stNm': '대구대',
#   'edNm': '서대구역',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000101014',
#   'routeNo': '101',
#   'routeNote': '덕곡방면(서촌로경유-상하행)',
#   'routeTCd': '3',
#   'stBsId': '7011022000',
#   'edBsId': '7011022000',
#   'stNm': '파계사',
#   'edNm': '파계사',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000101115',
#   'routeNo': '101-1',
#   'routeNote': '덕곡방면(휴일,서촌로경유-상행)',
#   'routeTCd': '3',
#   'stBsId': '7011022000',
#   'edBsId': '7011022000',
#   'stNm': '파계사',
#   'edNm': '파계사',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000101116',
#   'routeNo': '101-1',
#   'routeNote': '덕곡방면(서촌로경유-하행)',
#   'routeTCd': '3',
#   'stBsId': '7011022000',
#   'edBsId': '7011022000',
#   'stNm': '파계사',
#   'edNm': '파계사',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000101117',
#   'routeNo': '101-1',
#   'routeNote': '덕곡방면(휴일,서촌로경유-하행)',
#   'routeTCd': '3',
#   'stBsId': '7011022000',
#   'edBsId': '7011022000',
#   'stNm': '파계사',
#   'edNm': '파계사',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000707000',
#   'routeNo': '707',
#   'routeTCd': '3',
#   'stBsId': '7021054900',
#   'edBsId': '7021055000',
#   'stNm': '관음동',
#   'edNm': '관음동',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4050010000',
#   'routeNo': '동구10',
#   'routeTCd': '4',
#   'stBsId': '7011038200',
#   'edBsId': '7011037900',
#   'stNm': '반야월역',
#   'edNm': '반야월역',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000848000',
#   'routeNo': '848',
#   'routeNote': '동호-망우당공원-동호',
#   'routeTCd': '3',
#   'stBsId': '7011067500',
#   'edBsId': '7011067600',
#   'stNm': '동호지구',
#   'edNm': '동호지구',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000848001',
#   'routeNo': '848',
#   'routeNote': '동호(금강)-망우당공원-동호(금강)',
#   'routeTCd': '3',
#   'stBsId': '7011032300',
#   'edBsId': '7011032300',
#   'stNm': '금강동',
#   'edNm': '금강동',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4050001101',
#   'routeNo': '동구1-1',
#   'routeTCd': '4',
#   'stBsId': '7011034500',
#   'edBsId': '7011034500',
#   'stNm': '조일고등학교',
#   'edNm': '조일고등학교',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4050007001',
#   'routeNo': '동구7',
#   'routeTCd': '4',
#   'stBsId': '7011067500',
#   'edBsId': '7011067600',
#   'stNm': '동호지구',
#   'edNm': '동호지구',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4050008001',
#   'routeNo': '동구8',
#   'routeTCd': '4',
#   'stBsId': '7021064600',
#   'edBsId': '7021062600',
#   'stNm': '연경동',
#   'edNm': '연경동',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4060003002',
#   'routeNo': '북구3',
#   'routeTCd': '4',
#   'stBsId': '7021029700',
#   'edBsId': '7011067600',
#   'stNm': '노곡동',
#   'edNm': '동호지구',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4070002028',
#   'routeNo': '성서2',
#   'routeNote': '대천-대평-대천',
#   'routeTCd': '4',
#   'stBsId': '7041060400',
#   'edBsId': '7181072900',
#   'stNm': '대천동공영차고지',
#   'edNm': '대평리',
#   'dirRouteNote': '대천',
#   'ndirRouteNote': '대천',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4070002029',
#   'routeNo': '성서2',
#   'routeNote': '대천-하산스무지-대천',
#   'routeTCd': '4',
#   'stBsId': '7041060400',
#   'edBsId': '7111038600',
#   'stNm': '대천동공영차고지',
#   'edNm': '하산스무지',
#   'dirRouteNote': '대천',
#   'ndirRouteNote': '하산스무지',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4070002030',
#   'routeNo': '성서2',
#   'routeNote': '대천-강정-육신사-강정-대천',
#   'routeTCd': '4',
#   'stBsId': '7041060400',
#   'edBsId': '7111029900',
#   'stNm': '대천동공영차고지',
#   'edNm': '육신사',
#   'dirRouteNote': '대천',
#   'ndirRouteNote': '육신사',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4070002031',
#   'routeNo': '성서2',
#   'routeNote': '대천-하산스무지(육신사)-대천',
#   'routeTCd': '4',
#   'stBsId': '7041060400',
#   'edBsId': '7111038600',
#   'stNm': '대천동공영차고지',
#   'edNm': '하산스무지',
#   'dirRouteNote': '대천',
#   'ndirRouteNote': '하산스무지',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4070002039',
#   'routeNo': '성서2',
#   'routeNote': '대천-하산스무지-문산-대천',
#   'routeTCd': '4',
#   'stBsId': '7041060400',
#   'edBsId': '7111038600',
#   'stNm': '대천동',
#   'edNm': '하산스무지',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4040006022',
#   'routeNo': '달성6',
#   'routeTCd': '4',
#   'stBsId': '7111089800',
#   'edBsId': '7111026400',
#   'stNm': '현풍터미널',
#   'edNm': '본말',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4040007011',
#   'routeNo': '달성7',
#   'routeTCd': '4',
#   'stBsId': '7111089800',
#   'edBsId': '7111038900',
#   'stNm': '현풍터미널',
#   'edNm': '유산',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000520000',
#   'routeNo': '520',
#   'routeTCd': '3',
#   'stBsId': '7111026900',
#   'edBsId': '7111027000',
#   'stNm': '매곡리',
#   'edNm': '매곡리',
#   'dataconnareacd': 'DG'},
#  {'routeId': '1000008004',
#   'routeNo': '급행8',
#   'routeTCd': '1',
#   'stBsId': '7111084700',
#   'edBsId': '7031021600',
#   'stNm': '달성2차산업단지',
#   'edNm': '서대구역',
#   'dataconnareacd': 'DG'},
#  {'routeId': '1000008101',
#   'routeNo': '급행8-1',
#   'routeTCd': '1',
#   'stBsId': '7111077600',
#   'edBsId': '7041019900',
#   'stNm': '유곡리',
#   'edNm': '진천역',
#   'dataconnareacd': 'DG'},
#  {'routeId': '1000009002',
#   'routeNo': '급행9',
#   'routeTCd': '1',
#   'stBsId': '7021062000',
#   'edBsId': '7361003900',
#   'stNm': '동호동',
#   'edNm': '군위군청',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000304001',
#   'routeNo': '304',
#   'routeTCd': '3',
#   'stBsId': '7021049500',
#   'edBsId': '7111045800',
#   'stNm': '종합유통단지',
#   'edNm': '삼산리',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000309002',
#   'routeNo': '309',
#   'routeTCd': '3',
#   'stBsId': '7031021500',
#   'edBsId': '7121006100',
#   'stNm': '서대구역',
#   'edNm': '부적리',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000232000',
#   'routeNo': '232',
#   'routeTCd': '3',
#   'stBsId': '7111069100',
#   'edBsId': '7111069100',
#   'stNm': '방천리',
#   'edNm': '방천리',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3600842110',
#   'routeNo': '818',
#   'routeNote': '황제->북리->안심->북리->진량황제A동편',
#   'routeTCd': 'G',
#   'stBsId': '3600056400',
#   'edBsId': '3600056200',
#   'stNm': '진량황제A(진량방향)',
#   'edNm': '진량황제A',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3600842820',
#   'routeNo': '100',
#   'routeNote': '한의대(오성)->경산시장->정평역',
#   'routeTCd': 'G',
#   'stBsId': '3600011000',
#   'edBsId': '3600124300',
#   'stNm': '한의대(경산방향)',
#   'edNm': '한의대종점',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3600842840',
#   'routeNo': '100',
#   'routeNote': '한의대(오성)->경산시장',
#   'routeTCd': 'G',
#   'stBsId': '3600011000',
#   'edBsId': '3600124300',
#   'stNm': '한의대(경산방향)',
#   'edNm': '한의대종점',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3600842830',
#   'routeNo': '100',
#   'routeNote': '한의대(오성)->윤성->삼주->윤성->영남대',
#   'routeTCd': 'G',
#   'stBsId': '3600112800',
#   'edBsId': '7121005800',
#   'stNm': '한의대오성캠퍼스 후문',
#   'edNm': '영남대 건너',
#   'dataconnareacd': 'GS'},
#  {'routeId': '1000009200',
#   'routeNo': '급행9-2',
#   'routeTCd': '1',
#   'stBsId': '7021062000',
#   'edBsId': '7361009912',
#   'stNm': '동호동',
#   'edNm': '삼국유사면문화관',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000320000',
#   'routeNo': '320',
#   'routeTCd': '3',
#   'stBsId': '7021045600',
#   'edBsId': '7051014400',
#   'stNm': '검단동',
#   'edNm': '앞산공원',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000101013',
#   'routeNo': '101',
#   'routeNote': '덕곡방면(서촌로경유-하행)',
#   'routeTCd': '3',
#   'stBsId': '7011022000',
#   'edBsId': '7011022000',
#   'stNm': '파계사',
#   'edNm': '파계사',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000101015',
#   'routeNo': '101',
#   'routeNote': '덕곡방면(서촌로경유-하행, 덕곡구길 상행)',
#   'routeTCd': '3',
#   'stBsId': '7011022000',
#   'edBsId': '7011022000',
#   'stNm': '파계사',
#   'edNm': '파계사',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000101016',
#   'routeNo': '101',
#   'routeNote': '파계사방면',
#   'routeTCd': '3',
#   'stBsId': '7011022000',
#   'edBsId': '7011022000',
#   'stNm': '파계사',
#   'edNm': '파계사',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000101018',
#   'routeNo': '101',
#   'routeNote': '덕곡방면(휴일)',
#   'routeTCd': '3',
#   'stBsId': '7011022000',
#   'edBsId': '7011022000',
#   'stNm': '파계사',
#   'edNm': '파계사',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000101019',
#   'routeNo': '101',
#   'routeNote': '덕곡방면(휴일,서촌로경유-상행)',
#   'routeTCd': '3',
#   'stBsId': '7011022000',
#   'edBsId': '7011022000',
#   'stNm': '파계사',
#   'edNm': '파계사',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4060005000',
#   'routeNo': '북구5',
#   'routeTCd': '4',
#   'stBsId': '7021001400',
#   'edBsId': '7021001500',
#   'stNm': '관음동공영차고지',
#   'edNm': '관음동공영차고지',
#   'dataconnareacd': 'DG'},
#  {'routeId': '5000001000',
#   'routeNo': '직행1',
#   'routeTCd': '7',
#   'stBsId': '7021054000',
#   'edBsId': '7121005700',
#   'stNm': '학청청아람',
#   'edNm': '영남대학교',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4040002048',
#   'routeNo': '달성2',
#   'routeNote': '미진이지비아',
#   'routeTCd': '4',
#   'stBsId': '7041060400',
#   'edBsId': '7041053100',
#   'stNm': '대천동공영차고지',
#   'edNm': '대천동공영차고지',
#   'dataconnareacd': 'DG'},
#  {'routeId': '7361107011',
#   'routeNo': '군위7',
#   'routeNote': '낙전-화수-의흥-우보-군위',
#   'routeTCd': '6',
#   'stBsId': '7361000638',
#   'edBsId': '7361000281',
#   'stNm': '군위터미널',
#   'edNm': '군위터미널',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000309082',
#   'routeNo': '309',
#   'routeNote': '대구스타디움',
#   'routeTCd': '3',
#   'stBsId': '7031021500',
#   'edBsId': '7121006100',
#   'stNm': '서대구역',
#   'edNm': '부적리',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000349010',
#   'routeNo': '349',
#   'routeNote': '대구스타디움',
#   'routeTCd': '3',
#   'stBsId': '7061059600',
#   'edBsId': '7021047100',
#   'stNm': '시지지구',
#   'edNm': '종합유통단지',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000509098',
#   'routeNo': '509',
#   'routeNote': '대구스타디움',
#   'routeTCd': '3',
#   'stBsId': '7111069100',
#   'edBsId': '7121054600',
#   'stNm': '방천리',
#   'edNm': '경산 사동',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000649080',
#   'routeNo': '649',
#   'routeNote': '대구스타디움',
#   'routeTCd': '3',
#   'stBsId': '7041062100',
#   'edBsId': '7121020700',
#   'stNm': '대곡지구',
#   'edNm': '금구리',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000724096',
#   'routeNo': '724',
#   'routeNote': '대구스타디움',
#   'routeTCd': '3',
#   'stBsId': '7021041700',
#   'edBsId': '7061040500',
#   'stNm': '관음동',
#   'edNm': '신매동',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000848004',
#   'routeNo': '848',
#   'routeNote': '대구스타디움',
#   'routeTCd': '3',
#   'stBsId': '7011067500',
#   'edBsId': '7011067600',
#   'stNm': '동호지구',
#   'edNm': '동호지구',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000937088',
#   'routeNo': '937',
#   'routeNote': '대구스타디움',
#   'routeTCd': '3',
#   'stBsId': '7061059600',
#   'edBsId': '7021055000',
#   'stNm': '시지지구',
#   'edNm': '관음동(공영차고지)',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4080003103',
#   'routeNo': '수성3-1',
#   'routeNote': '대구스타디움',
#   'routeTCd': '4',
#   'stBsId': '7011038200',
#   'edBsId': '7011037900',
#   'stNm': '반야월역',
#   'edNm': '반야월역',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000894000',
#   'routeNo': '894',
#   'routeTCd': '3',
#   'stBsId': '7121054800',
#   'edBsId': '7061021300',
#   'stNm': '경일대학교',
#   'edNm': '범물동',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000101011',
#   'routeNo': '101',
#   'routeNote': '덕곡방면',
#   'routeTCd': '3',
#   'stBsId': '7011022000',
#   'edBsId': '7011022000',
#   'stNm': '파계사',
#   'edNm': '파계사',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000101012',
#   'routeNo': '101',
#   'routeNote': '덕곡방면(서촌로경유-상행)',
#   'routeTCd': '3',
#   'stBsId': '7011022000',
#   'edBsId': '7011022000',
#   'stNm': '파계사',
#   'edNm': '파계사',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000101017',
#   'routeNo': '101',
#   'routeNote': '파계사방면(휴일)',
#   'routeTCd': '3',
#   'stBsId': '7011022000',
#   'edBsId': '7011022000',
#   'stNm': '파계사',
#   'edNm': '파계사',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000101020',
#   'routeNo': '101',
#   'routeNote': '덕곡방면(휴일,서촌로경유-하행)',
#   'routeTCd': '3',
#   'stBsId': '7011022000',
#   'edBsId': '7011022000',
#   'stNm': '파계사',
#   'edNm': '파계사',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000101110',
#   'routeNo': '101-1',
#   'routeNote': '파계사방면',
#   'routeTCd': '3',
#   'stBsId': '7011022000',
#   'edBsId': '7011022000',
#   'stNm': '파계사',
#   'edNm': '파계사',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000101111',
#   'routeNo': '101-1',
#   'routeNote': '덕곡방면',
#   'routeTCd': '3',
#   'stBsId': '7011022000',
#   'edBsId': '7011022000',
#   'stNm': '파계사',
#   'edNm': '파계사',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4060002002',
#   'routeNo': '북구2',
#   'routeTCd': '4',
#   'stBsId': '7011052900',
#   'edBsId': '7001000800',
#   'stNm': '봉무공원',
#   'edNm': '청라언덕역',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3600841160',
#   'routeNo': '399',
#   'routeNote': '조곡->자인->정평',
#   'routeTCd': 'G',
#   'stBsId': '3600096000',
#   'edBsId': '3600041700',
#   'stNm': '조곡종점',
#   'edNm': '자인정류장',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3600842340',
#   'routeNo': '399',
#   'routeNote': '조곡->마곡,진량->고속터미널->자인',
#   'routeTCd': 'G',
#   'stBsId': '3600096000',
#   'edBsId': '3600041700',
#   'stNm': '조곡종점',
#   'edNm': '자인정류장',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3600843010',
#   'routeNo': '989-1',
#   'routeNote': '한의대->자인->대구대->임당->한의대',
#   'routeTCd': 'G',
#   'stBsId': '3600050200',
#   'edBsId': '3600050100',
#   'stNm': '대경대(경산방향)',
#   'edNm': '대경대',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3600843080',
#   'routeNo': '949',
#   'routeNote': '한의대->수성알파시티역',
#   'routeTCd': 'G',
#   'stBsId': '3600011000',
#   'edBsId': '3600124300',
#   'stNm': '한의대(경산방향)',
#   'edNm': '한의대종점',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3600843180',
#   'routeNo': '999-1',
#   'routeNote': '한의대->사동->경산역->신대->한의대',
#   'routeTCd': 'G',
#   'stBsId': '3600011000',
#   'edBsId': '3600124300',
#   'stNm': '한의대(경산방향)',
#   'edNm': '한의대종점',
#   'dataconnareacd': 'GS'},
#  {'routeId': '4040002044',
#   'routeNo': '달성2',
#   'routeNote': '노이',
#   'routeTCd': '4',
#   'stBsId': '7041060400',
#   'edBsId': '7041053100',
#   'stNm': '대천동',
#   'edNm': '대천동',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4040002045',
#   'routeNo': '달성2',
#   'routeNote': '마비정',
#   'routeTCd': '4',
#   'stBsId': '7041060400',
#   'edBsId': '7041053100',
#   'stNm': '대천동',
#   'edNm': '대천동',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4070002032',
#   'routeNo': '성서2',
#   'routeNote': '대천-기곡(대평,상당,터실)-대천',
#   'routeTCd': '4',
#   'stBsId': '7041060400',
#   'edBsId': '7111029600',
#   'stNm': '대천동공영차고지',
#   'edNm': '기곡',
#   'dirRouteNote': '대천',
#   'ndirRouteNote': '대천',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4080002005',
#   'routeNo': '수성2',
#   'routeNote': '시지-팔현-연호네거리(이천)',
#   'routeTCd': '4',
#   'stBsId': '7061059600',
#   'edBsId': '7061040500',
#   'stNm': '덕원고등학교',
#   'edNm': '시지(종점)',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4080003002',
#   'routeNo': '수성3',
#   'routeTCd': '4',
#   'stBsId': '7011038200',
#   'edBsId': '7011037900',
#   'stNm': '반야월역',
#   'edNm': '반야월역',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4080004001',
#   'routeNo': '수성4',
#   'routeTCd': '4',
#   'stBsId': '7061021400',
#   'edBsId': '7061021300',
#   'stNm': '범물동',
#   'edNm': '범물동',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4090001001',
#   'routeNo': '칠곡1',
#   'routeTCd': '4',
#   'stBsId': '7021001400',
#   'edBsId': '7021001500',
#   'stNm': '관음동공영차고지',
#   'edNm': '관음동공영차고지',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4090001101',
#   'routeNo': '칠곡1-1',
#   'routeTCd': '4',
#   'stBsId': '7021001400',
#   'edBsId': '7021001500',
#   'stNm': '관음동공영차고지',
#   'edNm': '관음동공영차고지',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4090002016',
#   'routeNo': '칠곡2',
#   'routeNote': '동호동-노곡동-동호동',
#   'routeTCd': '4',
#   'stBsId': '7021062000',
#   'edBsId': '7021029700',
#   'stNm': '동호동(영진교통)',
#   'edNm': '노곡동',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4090002017',
#   'routeNo': '칠곡2',
#   'routeNote': '추동교-노곡동-동호동',
#   'routeTCd': '4',
#   'stBsId': '7181002700',
#   'edBsId': '7021029700',
#   'stNm': '추동교',
#   'edNm': '노곡동',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4090002018',
#   'routeNo': '칠곡2',
#   'routeNote': '칠곡농장-노곡동-동호동',
#   'routeTCd': '4',
#   'stBsId': '7181004100',
#   'edBsId': '7021029700',
#   'stNm': '칠곡농장',
#   'edNm': '동호동',
#   'dataconnareacd': 'DG'},
#  {'routeId': '1000002001',
#   'routeNo': '급행2',
#   'routeTCd': '1',
#   'stBsId': '7111088100',
#   'edBsId': '7021061900',
#   'stNm': '냉천리',
#   'edNm': '동호동(북구)',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000240001',
#   'routeNo': '240',
#   'routeTCd': '3',
#   'stBsId': '7111069100',
#   'edBsId': '7111088100',
#   'stNm': '방천리',
#   'edNm': '냉천리',
#   'dataconnareacd': 'DG'},
#  {'routeId': '5000002000',
#   'routeNo': '직행2',
#   'routeTCd': '7',
#   'stBsId': '7111084700',
#   'edBsId': '7011067300',
#   'stNm': '달성2차산업단지',
#   'edNm': '동대구역복합환승센터',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3600842970',
#   'routeNo': '803-1',
#   'routeNote': '중산지구->대구대->중산지구',
#   'routeTCd': 'G',
#   'stBsId': '3600050200',
#   'edBsId': '3600050100',
#   'stNm': '대경대(경산방향)',
#   'edNm': '대경대',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3600842890',
#   'routeNo': '399',
#   'routeNote': '갈고개->자인->터미널->경산시장',
#   'routeTCd': 'G',
#   'stBsId': '3600041700',
#   'edBsId': '3600062200',
#   'stNm': '자인정류장',
#   'edNm': '경산시장',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3600842910',
#   'routeNo': '100',
#   'routeNote': '한의대(오성)->황금동->한의대(오성)',
#   'routeTCd': 'G',
#   'stBsId': '3600011000',
#   'edBsId': '3600124300',
#   'stNm': '한의대(경산방향)',
#   'edNm': '한의대종점',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3600842920',
#   'routeNo': '100',
#   'routeNote': '한의대(오성)->황금동->한의대(오성)1',
#   'routeTCd': 'G',
#   'stBsId': '3600011000',
#   'edBsId': '3600124300',
#   'stNm': '한의대(경산방향)',
#   'edNm': '한의대종점',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3600841240',
#   'routeNo': '990',
#   'routeNote': '내촌->자인->터미널->자인',
#   'routeTCd': 'G',
#   'stBsId': '7121029500',
#   'edBsId': '3600050100',
#   'stNm': '내촌마을회관',
#   'edNm': '대경대',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3600842800',
#   'routeNo': '990',
#   'routeNote': '자인->대신동->경산시장',
#   'routeTCd': 'G',
#   'stBsId': '3600041700',
#   'edBsId': '3600041700',
#   'stNm': '자인정류장',
#   'edNm': '자인정류장',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3601010960',
#   'routeNo': '990',
#   'routeNote': '대경대->자인->대신동->자인->갈고개',
#   'routeTCd': 'G',
#   'stBsId': '3600054000',
#   'edBsId': '3660000100',
#   'stNm': '송림리(용성방향)',
#   'edNm': '갈고개휴게소',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3601011000',
#   'routeNo': '990',
#   'routeNote': '자인->대신동->자인->내촌',
#   'routeTCd': 'G',
#   'stBsId': '7121029500',
#   'edBsId': '3600050100',
#   'stNm': '내촌마을회관',
#   'edNm': '대경대',
#   'dataconnareacd': 'GS'},
#  {'routeId': '4080006000',
#   'routeNo': '수성6',
#   'routeTCd': '4',
#   'stBsId': '7011046400',
#   'edBsId': '7011037900',
#   'stNm': '동호지구',
#   'edNm': '동호지구',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4120002000',
#   'routeNo': '서구2',
#   'routeTCd': '4',
#   'stBsId': '7111069100',
#   'edBsId': '7111069100',
#   'stNm': '방천리공영차고지',
#   'edNm': '방천리공영차고지',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000501000',
#   'routeNo': '501',
#   'routeTCd': '3',
#   'stBsId': '7041054300',
#   'edBsId': '7021062600',
#   'stNm': '성서산업단지',
#   'edNm': '연경동',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000326000',
#   'routeNo': '326',
#   'routeTCd': '3',
#   'stBsId': '7041060100',
#   'edBsId': '7021047100',
#   'stNm': '대곡동',
#   'edNm': '종합유통단지',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000509002',
#   'routeNo': '509',
#   'routeTCd': '3',
#   'stBsId': '7111069100',
#   'edBsId': '7121054600',
#   'stNm': '방천리',
#   'edNm': '경산 사동',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000402001',
#   'routeNo': '402',
#   'routeTCd': '3',
#   'stBsId': '7061021400',
#   'edBsId': '7031021600',
#   'stNm': '범물동',
#   'edNm': '서대구역',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000665000',
#   'routeNo': '665',
#   'routeNote': '달성2차산단-대천동',
#   'routeTCd': '3',
#   'stBsId': '7111084700',
#   'edBsId': '7041053100',
#   'stNm': '달성2차산업단지',
#   'edNm': '대천교',
#   'dirRouteNote': '대천동',
#   'ndirRouteNote': '달성2차산단',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3600842360',
#   'routeNo': '990',
#   'routeNote': '육동->자인->정평역',
#   'routeTCd': 'G',
#   'stBsId': '3600053300',
#   'edBsId': '3600041700',
#   'stNm': '부일리(용성방향)',
#   'edNm': '자인정류장',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3000609007',
#   'routeNo': '609',
#   'routeTCd': '3',
#   'stBsId': '7041060400',
#   'edBsId': '7121020700',
#   'stNm': '대천동',
#   'edNm': '금구리',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000814001',
#   'routeNo': '814',
#   'routeTCd': '3',
#   'stBsId': '7121021100',
#   'edBsId': '7061060000',
#   'stNm': '대구대학교',
#   'edNm': '범물동',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000836001',
#   'routeNo': '836',
#   'routeTCd': '3',
#   'stBsId': '7011067500',
#   'edBsId': '7041053100',
#   'stNm': '동호지구',
#   'edNm': '대천동',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000101112',
#   'routeNo': '101-1',
#   'routeNote': '파계사방면(휴일)',
#   'routeTCd': '3',
#   'stBsId': '7011022000',
#   'edBsId': '7011022000',
#   'stNm': '파계사',
#   'edNm': '파계사',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000101113',
#   'routeNo': '101-1',
#   'routeNote': '덕곡방면(휴일)',
#   'routeTCd': '3',
#   'stBsId': '7011022000',
#   'edBsId': '7011022000',
#   'stNm': '파계사',
#   'edNm': '파계사',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4060005001',
#   'routeNo': '북구5',
#   'routeNote': '도덕마을경유',
#   'routeTCd': '4',
#   'stBsId': '7021001400',
#   'edBsId': '7021001500',
#   'stNm': '관음동공영차고지',
#   'edNm': '관음동공영차고지',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4070002035',
#   'routeNo': '성서2',
#   'routeNote': '대천-하산스무지(대구보훈요양원)-대천',
#   'routeTCd': '4',
#   'stBsId': '7041060400',
#   'edBsId': '7111038600',
#   'stNm': '대천동공영차고지',
#   'edNm': '하산스무지',
#   'dirRouteNote': '대곡',
#   'ndirRouteNote': '대곡',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4070002036',
#   'routeNo': '성서2',
#   'routeNote': '대천-기곡(육신사,도채)-대천',
#   'routeTCd': '4',
#   'stBsId': '7041060400',
#   'edBsId': '7111029600',
#   'stNm': '대천동공영차고지',
#   'edNm': '기곡',
#   'dirRouteNote': '대천',
#   'ndirRouteNote': '육신사',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4070002037',
#   'routeNo': '성서2',
#   'routeNote': '대천-강정-기곡(육신사,도채)-강정-대천',
#   'routeTCd': '4',
#   'stBsId': '7041060400',
#   'edBsId': '7111029600',
#   'stNm': '대천동공영차고지',
#   'edNm': '기곡',
#   'dirRouteNote': '대천',
#   'ndirRouteNote': '육신사',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000101114',
#   'routeNo': '101-1',
#   'routeNote': '덕곡방면(서촌로경유-상행)',
#   'routeTCd': '3',
#   'stBsId': '7011022000',
#   'edBsId': '7011022000',
#   'stNm': '파계사',
#   'edNm': '파계사',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4030003002',
#   'routeNo': '달서3',
#   'routeTCd': '4',
#   'stBsId': '7041054300',
#   'edBsId': '7111019200',
#   'stNm': '성서산업단지',
#   'edNm': '화원유원지',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4030005001',
#   'routeNo': '달서5',
#   'routeTCd': '4',
#   'stBsId': '7041060100',
#   'edBsId': '7041054300',
#   'stNm': '대곡동',
#   'edNm': '성서산업단지',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4040002046',
#   'routeNo': '달성2',
#   'routeNote': '달성군청',
#   'routeTCd': '4',
#   'stBsId': '7041060400',
#   'edBsId': '7041053100',
#   'stNm': '대천동',
#   'edNm': '대천동',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4040002047',
#   'routeNo': '달성2',
#   'routeNote': '용연사',
#   'routeTCd': '4',
#   'stBsId': '7041060400',
#   'edBsId': '7041053100',
#   'stNm': '대천동공영차고지',
#   'edNm': '대천동공영차고지',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4050001001',
#   'routeNo': '동구1',
#   'routeTCd': '4',
#   'stBsId': '7011034500',
#   'edBsId': '7011034500',
#   'stNm': '조일고등학교',
#   'edNm': '조일고등학교',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4070002038',
#   'routeNo': '성서2',
#   'routeNote': '대천-문산-하산스무지-대천',
#   'routeTCd': '4',
#   'stBsId': '7041060400',
#   'edBsId': '7111038600',
#   'stNm': '대천동공영차고지',
#   'edNm': '하산스무지',
#   'dirRouteNote': '대천',
#   'ndirRouteNote': '하산스무지',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4080002003',
#   'routeNo': '수성2',
#   'routeNote': '시지-팔현-연호네거리',
#   'routeTCd': '4',
#   'stBsId': '7061059600',
#   'edBsId': '7061040500',
#   'stNm': '덕원고등학교',
#   'edNm': '시지(종점)',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4080002004',
#   'routeNo': '수성2',
#   'routeNote': '시지-팔현-연호네거리(연호)',
#   'routeTCd': '4',
#   'stBsId': '7061059600',
#   'edBsId': '7061040500',
#   'stNm': '덕원고등학교',
#   'edNm': '시지(종점)',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4080003102',
#   'routeNo': '수성3-1',
#   'routeTCd': '4',
#   'stBsId': '7011038200',
#   'edBsId': '7011037900',
#   'stNm': '반야월역',
#   'edNm': '반야월역',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000848002',
#   'routeNo': '848',
#   'routeNote': '동호(금강)-망우당공원-동호',
#   'routeTCd': '3',
#   'stBsId': '7011032300',
#   'edBsId': '7011067600',
#   'stNm': '금강동',
#   'edNm': '동호지구',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000848003',
#   'routeNo': '848',
#   'routeNote': '동호-망우당공원-동호(금강)',
#   'routeTCd': '3',
#   'stBsId': '7011067500',
#   'edBsId': '7011032300',
#   'stNm': '동호지구',
#   'edNm': '금강동',
#   'dataconnareacd': 'DG'},
#  {'routeId': '7361106012',
#   'routeNo': '군위6',
#   'routeNote': '군위-우보-의흥-화수-삼국유사-화수2-신녕',
#   'routeTCd': '6',
#   'stBsId': '7361000638',
#   'edBsId': '7361000281',
#   'stNm': '군위터미널',
#   'edNm': '군위터미널',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3600843220',
#   'routeNo': '803-1',
#   'routeNote': '중산지구->초원->대구대->중산지구',
#   'routeTCd': 'G',
#   'stBsId': '3600050200',
#   'edBsId': '3600050100',
#   'stNm': '대경대(경산방향)',
#   'edNm': '대경대',
#   'dataconnareacd': 'GS'},
#  {'routeId': '4060007000',
#   'routeNo': '북구7',
#   'routeTCd': '4',
#   'stBsId': '7021041700',
#   'edBsId': '7021001600',
#   'stNm': '관음동',
#   'edNm': '관음동',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4060008000',
#   'routeNo': '북구8',
#   'routeTCd': '4',
#   'stBsId': '7021054900',
#   'edBsId': '7021055000',
#   'stNm': '관음동공영차고지',
#   'edNm': '관음동공영차고지',
#   'dataconnareacd': 'DG'},
#  {'routeId': '1000010000',
#   'routeNo': '급행10',
#   'routeTCd': '1',
#   'stBsId': '7041060400',
#   'edBsId': '7011037900',
#   'stNm': '대천동',
#   'edNm': '반야월역',
#   'dataconnareacd': 'DG'},
#  {'routeId': '1000009300',
#   'routeNo': '급행9-3',
#   'routeTCd': '1',
#   'stBsId': '7021062000',
#   'edBsId': '7361009916',
#   'stNm': '동호동',
#   'edNm': '소보시장',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000725000',
#   'routeNo': '725',
#   'routeTCd': '5',
#   'stBsId': '7021062000',
#   'edBsId': '7111027000',
#   'stNm': '동호동(북구)',
#   'edNm': '매곡리',
#   'dataconnareacd': 'DG'},
#  {'routeId': '1000009100',
#   'routeNo': '급행9-1',
#   'routeTCd': '1',
#   'stBsId': '7021062000',
#   'edBsId': '7361000549',
#   'stNm': '동호동',
#   'edNm': '우보정류장',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000518002',
#   'routeNo': '518',
#   'routeTCd': '3',
#   'stBsId': '7041054300',
#   'edBsId': '7011019400',
#   'stNm': '성서산업단지',
#   'edNm': '안심역',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000523002',
#   'routeNo': '523',
#   'routeTCd': '3',
#   'stBsId': '7021045600',
#   'edBsId': '7111069100',
#   'stNm': '검단동',
#   'edNm': '방천리',
#   'dataconnareacd': 'DG'},
#  {'routeId': '7361106011',
#   'routeNo': '군위6',
#   'routeNote': '군위-효령-구효령-매곡',
#   'routeTCd': '6',
#   'stBsId': '7361000638',
#   'edBsId': '7361000281',
#   'stNm': '군위터미널',
#   'edNm': '군위터미널',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000618003',
#   'routeNo': '618',
#   'routeTCd': '3',
#   'stBsId': '7041020600',
#   'edBsId': '7011067600',
#   'stNm': '대곡지구',
#   'edNm': '동호지구',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000623002',
#   'routeNo': '623',
#   'routeTCd': '3',
#   'stBsId': '7111030100',
#   'edBsId': '7021066200',
#   'stNm': '달성군청',
#   'edNm': '검단동',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000650005',
#   'routeNo': '650',
#   'routeTCd': '3',
#   'stBsId': '7171003700',
#   'edBsId': '7011067300',
#   'stNm': '다산면',
#   'edNm': '동대구역복합환승센터',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000665003',
#   'routeNo': '665',
#   'routeNote': '대곡-용연사-유가사(토·공휴일)',
#   'routeTCd': '3',
#   'stBsId': '7111000100',
#   'edBsId': '7111024400',
#   'stNm': '대곡역',
#   'edNm': '유가사',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3600842960',
#   'routeNo': '949',
#   'routeNote': '한의대->만촌네거리->한의대',
#   'routeTCd': 'G',
#   'stBsId': '3600011000',
#   'edBsId': '3600124300',
#   'stNm': '한의대(경산방향)',
#   'edNm': '한의대종점',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3600842980',
#   'routeNo': '912',
#   'routeNote': '대경대->중산->공단->대경대',
#   'routeTCd': 'G',
#   'stBsId': '3600050200',
#   'edBsId': '3600050100',
#   'stNm': '대경대(경산방향)',
#   'edNm': '대경대',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3600842990',
#   'routeNo': '913',
#   'routeNote': '자인->무학지구->지식산업단지->자인정류장',
#   'routeTCd': 'G',
#   'stBsId': '3600050200',
#   'edBsId': '3600050100',
#   'stNm': '대경대(경산방향)',
#   'edNm': '대경대',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3600843000',
#   'routeNo': '989',
#   'routeNote': '한의대->임당->대구대->자인->한의대',
#   'routeTCd': 'G',
#   'stBsId': '3600050200',
#   'edBsId': '3600050100',
#   'stNm': '대경대(경산방향)',
#   'edNm': '대경대',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3600842370',
#   'routeNo': '990',
#   'routeNote': '내촌->자인->정평역',
#   'routeTCd': 'G',
#   'stBsId': '3600053300',
#   'edBsId': '3600041700',
#   'stNm': '부일리(용성방향)',
#   'edNm': '자인정류장',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3600843230',
#   'routeNo': '803-1',
#   'routeNote': '중산지구->대구대->초원->중산지구',
#   'routeTCd': 'G',
#   'stBsId': '3600050200',
#   'edBsId': '3600050100',
#   'stNm': '대경대(경산방향)',
#   'edNm': '대경대',
#   'dataconnareacd': 'GS'},
#  {'routeId': '4090003007',
#   'routeNo': '칠곡3',
#   'routeNote': '동명-칠곡시장-동명',
#   'routeTCd': '4',
#   'stBsId': '7181001100',
#   'edBsId': '7181001000',
#   'stNm': '동명면',
#   'edNm': '동명면',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4090003011',
#   'routeNo': '칠곡3',
#   'routeNote': '동명-칠곡시장-동명-경운대-동명',
#   'routeTCd': '4',
#   'stBsId': '7181007000',
#   'edBsId': '7181007000',
#   'stNm': '동명면',
#   'edNm': '동명면',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4110002000',
#   'routeNo': '팔공3',
#   'routeNote': '팔공산맞춤노선(토,휴일,공휴일운행)',
#   'routeTCd': '4',
#   'stBsId': '7021053200',
#   'edBsId': '7021053200',
#   'stNm': '칠곡경북대병원',
#   'edNm': '갓바위',
#   'dirRouteNote': '갓바위',
#   'ndirRouteNote': '칠곡경북대병원',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4050003004',
#   'routeNo': '동구3',
#   'routeNote': 'K2관사방면(둔산경유)',
#   'routeTCd': '4',
#   'stBsId': '7021024100',
#   'edBsId': '7011035800',
#   'stNm': '칠성시장',
#   'edNm': 'K2관사',
#   'dirRouteNote': 'K2관사',
#   'ndirRouteNote': '칠성시장',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4090003014',
#   'routeNo': '칠곡3',
#   'routeNote': '동명-칠곡시장-동명-경운대-예술대-동명',
#   'routeTCd': '4',
#   'stBsId': '7181007000',
#   'edBsId': '7181007000',
#   'stNm': '동명면',
#   'edNm': '동명면',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4090003015',
#   'routeNo': '칠곡3',
#   'routeNote': '동명-칠곡시장-동명-하판',
#   'routeTCd': '4',
#   'stBsId': '7181007000',
#   'edBsId': '7181002900',
#   'stNm': '동명면',
#   'edNm': '하판',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4090003017',
#   'routeNo': '칠곡3',
#   'routeNote': '동명-칠곡시장-동명-기성-파계사-동명',
#   'routeTCd': '4',
#   'stBsId': '7181007000',
#   'edBsId': '7011022000',
#   'stNm': '동명면',
#   'edNm': '파계사',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4040001006',
#   'routeNo': '달성1',
#   'routeNote': '다산-대곡-다산',
#   'routeTCd': '4',
#   'stBsId': '7171003700',
#   'edBsId': '7171003700',
#   'stNm': '고령다산',
#   'edNm': '고령다산',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4040001007',
#   'routeNo': '달성1',
#   'routeNote': '다산-대곡-득성-다산',
#   'routeTCd': '4',
#   'stBsId': '7171003700',
#   'edBsId': '7171003700',
#   'stNm': '고령다산',
#   'edNm': '고령다산',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4040001008',
#   'routeNo': '달성1',
#   'routeNote': '다산-대곡-노곡-다산',
#   'routeTCd': '4',
#   'stBsId': '7171003700',
#   'edBsId': '7171003700',
#   'stNm': '고령다산',
#   'edNm': '고령다산',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000937000',
#   'routeNo': '937',
#   'routeTCd': '3',
#   'stBsId': '7061059600',
#   'edBsId': '7021055000',
#   'stNm': '시지지구',
#   'edNm': '관음동(공영차고지)',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4010002004',
#   'routeNo': '가창2',
#   'routeNote': '정대방면',
#   'routeTCd': '4',
#   'stBsId': '7021051300',
#   'edBsId': '7021051300',
#   'stNm': '정대리',
#   'edNm': '정대리',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4070001000',
#   'routeNo': '성서1',
#   'routeTCd': '4',
#   'stBsId': '7111026900',
#   'edBsId': '7111027000',
#   'stNm': '매곡',
#   'edNm': '매곡',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4080001100',
#   'routeNo': '수성1-1',
#   'routeTCd': '4',
#   'stBsId': '7061021400',
#   'edBsId': '7061021300',
#   'stNm': '범물동',
#   'edNm': '범물동',
#   'dataconnareacd': 'DG'},
#  {'routeId': '2000002100',
#   'routeNo': '순환2-1',
#   'routeTCd': '2',
#   'stBsId': '7021045600',
#   'edBsId': '7021066200',
#   'stNm': '검단동',
#   'edNm': '검단동',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4070003007',
#   'routeNo': '성서3',
#   'routeNote': '다사-이천-팔달시장-이천-다사',
#   'routeTCd': '4',
#   'stBsId': '7111026900',
#   'edBsId': '7111027000',
#   'stNm': '매곡',
#   'edNm': '매곡',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4110001006',
#   'routeNo': '팔공2',
#   'routeNote': '팔공산맞춤노선(토요일,공휴일운행)',
#   'routeTCd': '4',
#   'stBsId': '7011008100',
#   'edBsId': '7011036000',
#   'stNm': '동대구',
#   'edNm': '갓바위',
#   'dirRouteNote': '갓바위',
#   'ndirRouteNote': '동대구역',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000425000',
#   'routeNo': '425',
#   'routeTCd': '3',
#   'stBsId': '7061059300',
#   'edBsId': '7111027000',
#   'stNm': '황금동',
#   'edNm': '매곡',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4070003008',
#   'routeNo': '성서3',
#   'routeNote': '다사-이천-장기-이천-다사',
#   'routeTCd': '4',
#   'stBsId': '7111026900',
#   'edBsId': '7111027000',
#   'stNm': '매곡',
#   'edNm': '매곡',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4040005070',
#   'routeNo': '달성5',
#   'routeNote': '대곡-용연사-휴양림-유가사(토·공휴일)',
#   'routeTCd': '4',
#   'stBsId': '7041053300',
#   'edBsId': '7111024400',
#   'stNm': '대곡',
#   'edNm': '유가사',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4040005071',
#   'routeNo': '달성5',
#   'routeNote': '유가사-용연사-대곡(토·공휴일)',
#   'routeTCd': '4',
#   'stBsId': '7111024400',
#   'edBsId': '7041053200',
#   'stNm': '유가사',
#   'edNm': '대곡',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4040005072',
#   'routeNo': '달성5',
#   'routeNote': '대곡-용연사-유가사(토·공휴일)',
#   'routeTCd': '4',
#   'stBsId': '7041053300',
#   'edBsId': '7111024400',
#   'stNm': '대곡',
#   'edNm': '유가사',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4090003013',
#   'routeNo': '칠곡3',
#   'routeNote': '동명-칠곡시장-동명-기성-동명',
#   'routeTCd': '4',
#   'stBsId': '7181007000',
#   'edBsId': '7181001000',
#   'stNm': '동명면',
#   'edNm': '동명면',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4070003003',
#   'routeNo': '성서3',
#   'routeNote': '다사-세천-장기-이천-다사',
#   'routeTCd': '4',
#   'stBsId': '7111026900',
#   'edBsId': '7111027000',
#   'stNm': '매곡',
#   'edNm': '매곡',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000655000',
#   'routeNo': '655',
#   'routeTCd': '3',
#   'stBsId': '7111026900',
#   'edBsId': '7111077601',
#   'stNm': '매곡',
#   'edNm': '유곡리',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3600840690',
#   'routeNo': '남산2',
#   'routeNote': '자인->원당->갈고개->원당->자인',
#   'routeTCd': 'G',
#   'stBsId': '3600041700',
#   'edBsId': '3600041700',
#   'stNm': '자인정류장',
#   'edNm': '자인정류장',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3601090010',
#   'routeNo': '809',
#   'routeNote': '하양->경일대,환상->문명고->하양',
#   'routeTCd': 'G',
#   'stBsId': '3600116600',
#   'edBsId': '3600116600',
#   'stNm': '하양청구2차정문',
#   'edNm': '하양청구2차정문',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3601040420',
#   'routeNo': '399',
#   'routeNote': '갈고개->경산시장->정평역',
#   'routeTCd': '91',
#   'stBsId': '3660000200',
#   'edBsId': '3600090700',
#   'stNm': '갈고개휴게소 건너',
#   'edNm': '정평역2번출구',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3000724000',
#   'routeNo': '724',
#   'routeTCd': '3',
#   'stBsId': '7021041700',
#   'edBsId': '7061040500',
#   'stNm': '관음동',
#   'edNm': '신매동',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3600840680',
#   'routeNo': '남산1',
#   'routeNote': '상대온천->정평역->유곡->상대온천',
#   'routeTCd': 'G',
#   'stBsId': '3600041700',
#   'edBsId': '3600009100',
#   'stNm': '자인정류장',
#   'edNm': '상대온천',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3601130010',
#   'routeNo': '109',
#   'routeNote': '한의대->영대->대경대->영대->한의대->여천,한의대(오성)',
#   'routeTCd': 'G',
#   'stBsId': '3600011000',
#   'edBsId': '3600112800',
#   'stNm': '한의대(경산방향)',
#   'edNm': '한의대오성캠퍼스 후문',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3601130020',
#   'routeNo': '109',
#   'routeNote': '한의대(오성),여천->한의대->영대->대경대->영대->한의대',
#   'routeTCd': 'G',
#   'stBsId': '3600112800',
#   'edBsId': '3600124300',
#   'stNm': '한의대오성캠퍼스 후문',
#   'edNm': '한의대종점',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3601130030',
#   'routeNo': '109',
#   'routeNote': '한의대(오성)->영대->강서,당리,남신->대경대->영대->한의대(오성)',
#   'routeTCd': 'G',
#   'stBsId': '3600112800',
#   'edBsId': '3600112800',
#   'stNm': '한의대오성캠퍼스 후문',
#   'edNm': '한의대오성캠퍼스 후문',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3604420050',
#   'routeNo': '용성1',
#   'routeNote': '자인->송림->자인',
#   'routeTCd': 'G',
#   'stBsId': '3600041700',
#   'edBsId': '3600041700',
#   'stNm': '자인정류장',
#   'edNm': '자인정류장',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3604410030',
#   'routeNo': '용성1',
#   'routeNote': '자인->곡란->자인',
#   'routeTCd': 'G',
#   'stBsId': '3600041700',
#   'edBsId': '3600041700',
#   'stNm': '자인정류장',
#   'edNm': '자인정류장',
#   'dataconnareacd': 'GS'},
#  {'routeId': '4070003010',
#   'routeNo': '성서3',
#   'routeNote': '다사-세천-팔달시장-세천-다사',
#   'routeTCd': '4',
#   'stBsId': '7111026900',
#   'edBsId': '7111027000',
#   'stNm': '매곡',
#   'edNm': '매곡',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3601060090',
#   'routeNo': '911',
#   'routeNote': '황제->경산고->옥산->공단->하양->황제->대경대',
#   'routeTCd': 'G',
#   'stBsId': '3600056400',
#   'edBsId': '3600050100',
#   'stNm': '진량황제A(진량방향)',
#   'edNm': '대경대',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3601010080',
#   'routeNo': '990',
#   'routeNote': '대경대->자인->대신동->자인->송림',
#   'routeTCd': 'G',
#   'stBsId': '3600050200',
#   'edBsId': '3600053900',
#   'stNm': '대경대(경산방향)',
#   'edNm': '송림리(매남방향)',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3601040310',
#   'routeNo': '399',
#   'routeNote': '사림,흥정,우검->자인->터미널->자인',
#   'routeTCd': 'G',
#   'stBsId': '3600003700',
#   'edBsId': '3600041700',
#   'stNm': '사림종점(남산방향)',
#   'edNm': '자인정류장',
#   'dataconnareacd': 'GS'},
#  {'routeId': '4060004000',
#   'routeNo': '북구4',
#   'routeTCd': '4',
#   'stBsId': '7111069100',
#   'edBsId': '7111069100',
#   'stNm': '방천리(공영차고지)',
#   'edNm': '방천리(공영차고지)',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4060004001',
#   'routeNo': '북구4',
#   'routeNote': '대구사격장경유',
#   'routeTCd': '4',
#   'stBsId': '7021056500',
#   'edBsId': '7021056600',
#   'stNm': '방천리(공영차고지)',
#   'edNm': '방천리(공영차고지)',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4050004000',
#   'routeNo': '동구4',
#   'routeTCd': '4',
#   'stBsId': '7011018400',
#   'edBsId': '7011067600',
#   'stNm': '동호동(공영차고지)',
#   'edNm': '동호동(공영차고지)',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4050004100',
#   'routeNo': '동구4-1',
#   'routeTCd': '4',
#   'stBsId': '7011067500',
#   'edBsId': '7011037900',
#   'stNm': '동호동(공영차고지)',
#   'edNm': '동호동(공영차고지)',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3601040370',
#   'routeNo': '399',
#   'routeNote': '상대->터미널->자인',
#   'routeTCd': 'G',
#   'stBsId': '3600009100',
#   'edBsId': '3600041700',
#   'stNm': '상대온천',
#   'edNm': '자인정류장',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3601070030',
#   'routeNo': '803',
#   'routeNote': '경산->갓바위->경산',
#   'routeTCd': 'G',
#   'stBsId': '7121002900',
#   'edBsId': '7121003000',
#   'stNm': '경남신성A 건너',
#   'edNm': '경남신성A',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3601070040',
#   'routeNo': '803',
#   'routeNote': '경산->갓바위->초원->경산',
#   'routeTCd': 'G',
#   'stBsId': '7121002900',
#   'edBsId': '7121003000',
#   'stNm': '경남신성A 건너',
#   'edNm': '경남신성A',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3601070050',
#   'routeNo': '803',
#   'routeNote': '경산->초원->갓바위->경산',
#   'routeTCd': 'G',
#   'stBsId': '7121002900',
#   'edBsId': '7121003000',
#   'stNm': '경남신성A 건너',
#   'edNm': '경남신성A',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3604820050',
#   'routeNo': '하양1',
#   'routeNote': '경일대->능성->소월입구->경일대',
#   'routeTCd': 'G',
#   'stBsId': '7121006900',
#   'edBsId': '3600064800',
#   'stNm': '경일대정문',
#   'edNm': '경일대정문 건너',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3601080080',
#   'routeNo': '918',
#   'routeNote': '한의대->백천->의송리->삼주->백천->한의대',
#   'routeTCd': 'G',
#   'stBsId': '3600011000',
#   'edBsId': '3600011000',
#   'stNm': '한의대(경산방향)',
#   'edNm': '한의대(경산방향)',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3601080090',
#   'routeNo': '918',
#   'routeNote': '한의대->백천->의송리->삼주->경산고->백천->한의대(단,오전 일부시간운행)',
#   'routeTCd': 'G',
#   'stBsId': '3600011000',
#   'edBsId': '3600011000',
#   'stNm': '한의대(경산방향)',
#   'edNm': '한의대(경산방향)',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3604620220',
#   'routeNo': '진량2',
#   'routeNote': '경일대->초원->경일대',
#   'routeTCd': 'G',
#   'stBsId': '7121006900',
#   'edBsId': '3600064800',
#   'stNm': '경일대정문',
#   'edNm': '경일대정문 건너',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3604620240',
#   'routeNo': '진량2',
#   'routeNote': '경일대->진량윤성->초원->경일대',
#   'routeTCd': 'G',
#   'stBsId': '7121054800',
#   'edBsId': '7121054700',
#   'stNm': '경일대종점',
#   'edNm': '경일대종점 건너',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3604620250',
#   'routeNo': '진량2',
#   'routeNote': '경일대->초원->진량윤성->경일대',
#   'routeTCd': 'G',
#   'stBsId': '7121006900',
#   'edBsId': '3600064800',
#   'stNm': '경일대정문',
#   'edNm': '경일대정문 건너',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3604620270',
#   'routeNo': '진량2',
#   'routeNote': '하양->진량->황제->하양',
#   'routeTCd': 'G',
#   'stBsId': '3600109400',
#   'edBsId': '7121006300',
#   'stNm': '하양시외버스터미널',
#   'edNm': '하양역 건너',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3600840420',
#   'routeNo': '진량1',
#   'routeNote': '하양->진량->문천2리->다문->자인->골프장->하양',
#   'routeTCd': 'G',
#   'stBsId': '3600109400',
#   'edBsId': '3600109400',
#   'stNm': '하양시외버스터미널',
#   'edNm': '하양시외버스터미널',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3604840120',
#   'routeNo': '와촌1',
#   'routeNote': '경일대->대동->은해사->청통->경일대',
#   'routeTCd': 'G',
#   'stBsId': '7121006900',
#   'edBsId': '3600064800',
#   'stNm': '경일대정문',
#   'edNm': '경일대정문 건너',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3604610160',
#   'routeNo': '진량1',
#   'routeNote': '하양->진량->골프장->자인->문천2리->진량->하양',
#   'routeTCd': 'G',
#   'stBsId': '3600109400',
#   'edBsId': '3600109400',
#   'stNm': '하양시외버스터미널',
#   'edNm': '하양시외버스터미널',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3604820080',
#   'routeNo': '하양1',
#   'routeNote': '하양여고->경일대',
#   'routeTCd': 'G',
#   'stBsId': '3600073900',
#   'edBsId': '3600064800',
#   'stNm': '하양여중고',
#   'edNm': '경일대정문 건너',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3604820070',
#   'routeNo': '하양1',
#   'routeNote': '경일대->내리->경일대',
#   'routeTCd': 'G',
#   'stBsId': '7121006900',
#   'edBsId': '3600064800',
#   'stNm': '경일대정문',
#   'edNm': '경일대정문 건너',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3604610170',
#   'routeNo': '진량1',
#   'routeNote': '하양->진량->다문->아사->선안->마곡->자인',
#   'routeTCd': 'G',
#   'stBsId': '3600109400',
#   'edBsId': '3600041700',
#   'stNm': '하양시외버스터미널',
#   'edNm': '자인정류장',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3604510180',
#   'routeNo': '압량1',
#   'routeNote': '자인->남신->정평->남신->자인',
#   'routeTCd': 'G',
#   'stBsId': '3600041700',
#   'edBsId': '3600041700',
#   'stNm': '자인정류장',
#   'edNm': '자인정류장',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3601060160',
#   'routeNo': '911',
#   'routeNote': '황제->옥산->공단->하양->황제',
#   'routeTCd': 'G',
#   'stBsId': '3600056400',
#   'edBsId': '3600056400',
#   'stNm': '진량황제A(진량방향)',
#   'edNm': '진량황제A(진량방향)',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3604330280',
#   'routeNo': '남산2',
#   'routeNote': '자인->사림->자인',
#   'routeTCd': 'G',
#   'stBsId': '3600041700',
#   'edBsId': '3600041700',
#   'stNm': '자인정류장',
#   'edNm': '자인정류장',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3604330290',
#   'routeNo': '남산2',
#   'routeNote': '자인->우검->사림->자인',
#   'routeTCd': 'G',
#   'stBsId': '3600041700',
#   'edBsId': '3600041700',
#   'stNm': '자인정류장',
#   'edNm': '자인정류장',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3600841460',
#   'routeNo': '경산3',
#   'routeNote': '한의대->계남->자인->계남->한의대',
#   'routeTCd': 'G',
#   'stBsId': '3600011000',
#   'edBsId': '3600011000',
#   'stNm': '한의대(경산방향)',
#   'edNm': '한의대(경산방향)',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3000401078',
#   'routeNo': '401',
#   'routeNote': '능성동맞춤노선(평일,오전)',
#   'routeTCd': '3',
#   'stBsId': '7011036000',
#   'edBsId': '7061021300',
#   'stNm': '갓바위',
#   'edNm': '범물동',
#   'dirRouteNote': '갓바위',
#   'ndirRouteNote': '범물',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000401079',
#   'routeNo': '401',
#   'routeNote': '능성동맞춤노선(평일,오후)',
#   'routeTCd': '3',
#   'stBsId': '7011036000',
#   'edBsId': '7061021300',
#   'stNm': '갓바위',
#   'edNm': '범물동',
#   'dirRouteNote': '갓바위',
#   'ndirRouteNote': '범물',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4090003021',
#   'routeNo': '칠곡3',
#   'routeNote': '동명-칠곡시장-동명-기성-대구은행연수원-동명',
#   'routeTCd': '4',
#   'stBsId': '7181001200',
#   'edBsId': '7181001000',
#   'stNm': '기성리',
#   'edNm': '동명면',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3690000060',
#   'routeNo': '250',
#   'routeNote': '성주_광영_동곡_문양역_다사_반고개_북부',
#   'routeTCd': 'C',
#   'stBsId': '3680000790',
#   'edBsId': '7031016000',
#   'stNm': '성주터미널',
#   'edNm': '북부정류장',
#   'dataconnareacd': 'CG'},
#  {'routeId': '3690000070',
#   'routeNo': '250',
#   'routeNote': '북부_반고개_다사_문양역_동곡_광영_성주',
#   'routeTCd': 'C',
#   'stBsId': '7031016000',
#   'edBsId': '3680001160',
#   'stNm': '북부정류장',
#   'edNm': '성주터미널',
#   'dataconnareacd': 'CG'},
#  {'routeId': '3690000080',
#   'routeNo': '250',
#   'routeNote': '성주_광영_동곡_다사_반고개_북부',
#   'routeTCd': 'C',
#   'stBsId': '3680000790',
#   'edBsId': '7031016000',
#   'stNm': '성주터미널',
#   'edNm': '북부정류장',
#   'dataconnareacd': 'CG'},
#  {'routeId': '3690000190',
#   'routeNo': '250',
#   'routeNote': '북부_반고개_다사_동곡_광영_성주',
#   'routeTCd': 'C',
#   'stBsId': '7031016000',
#   'edBsId': '3680001160',
#   'stNm': '북부정류장',
#   'edNm': '성주터미널',
#   'dataconnareacd': 'CG'},
#  {'routeId': '3690003530',
#   'routeNo': '50',
#   'routeNote': '왜관북부정류장_노석_광영_문양역',
#   'routeTCd': 'C',
#   'stBsId': '3690000080',
#   'edBsId': '7111041900',
#   'stNm': '왜관북부',
#   'edNm': '문양기지창앞',
#   'dataconnareacd': 'CG'},
#  {'routeId': '3690003540',
#   'routeNo': '50',
#   'routeNote': '문양역_광영_노석_왜관북부정류장',
#   'routeTCd': 'C',
#   'stBsId': '7111042000',
#   'edBsId': '3690000080',
#   'stNm': '문양역건너',
#   'edNm': '왜관북부',
#   'dataconnareacd': 'CG'},
#  {'routeId': '3690003730',
#   'routeNo': '200',
#   'routeNote': '황학_신동_대구북부정류장',
#   'routeTCd': 'C',
#   'stBsId': '3690006800',
#   'edBsId': '7031016000',
#   'stNm': '황학종점',
#   'edNm': '북부정류장',
#   'dataconnareacd': 'CG'},
#  {'routeId': '3690003740',
#   'routeNo': '200',
#   'routeNote': '대구북부정류장_신동_황학',
#   'routeTCd': 'C',
#   'stBsId': '7031016000',
#   'edBsId': '3690005320',
#   'stNm': '북부정류장',
#   'edNm': '황학',
#   'dataconnareacd': 'CG'},
#  {'routeId': '3690003770',
#   'routeNo': '300 ',
#   'routeNote': '가산2리_용수_동명_대구북부정류장',
#   'routeTCd': 'C',
#   'stBsId': '3690005370',
#   'edBsId': '7031016000',
#   'stNm': '가산2리한뜸',
#   'edNm': '북부정류장',
#   'dataconnareacd': 'CG'},
#  {'routeId': '3690003780',
#   'routeNo': '300 ',
#   'routeNote': '대구북부정류장_동명_용수_가산2리',
#   'routeTCd': 'C',
#   'stBsId': '7031005800',
#   'edBsId': '3690005370',
#   'stNm': '북부정류장건너',
#   'edNm': '가산2리한뜸',
#   'dataconnareacd': 'CG'},
#  {'routeId': '3690003860',
#   'routeNo': '250',
#   'routeNote': '왜관북부정류장_연호_대구북부정류장',
#   'routeTCd': 'C',
#   'stBsId': '3690000080',
#   'edBsId': '7031016000',
#   'stNm': '왜관북부',
#   'edNm': '북부정류장',
#   'dataconnareacd': 'CG'},
#  {'routeId': '3690003880',
#   'routeNo': '250',
#   'routeNote': '대구북부정류장_연호_왜관북부정류장',
#   'routeTCd': 'C',
#   'stBsId': '7031016000',
#   'edBsId': '3690000080',
#   'stNm': '북부정류장',
#   'edNm': '왜관북부',
#   'dataconnareacd': 'CG'},
#  {'routeId': '3690003940',
#   'routeNo': '20',
#   'routeNote': '문양역_금남_공단_삼부_왜관북부정류장',
#   'routeTCd': 'C',
#   'stBsId': '7111042000',
#   'edBsId': '3690000080',
#   'stNm': '문양역건너',
#   'edNm': '왜관북부',
#   'dataconnareacd': 'CG'},
#  {'routeId': '3690003950',
#   'routeNo': '20',
#   'routeNote': '왜관북부정류장_삼부_공단_금남_문양역',
#   'routeTCd': 'C',
#   'stBsId': '3690000080',
#   'edBsId': '7111042000',
#   'stNm': '왜관북부',
#   'edNm': '문양역건너',
#   'dataconnareacd': 'CG'},
#  {'routeId': '3690004010',
#   'routeNo': '250-1',
# ...
#   'stNm': '자인정류장',
#   'edNm': '중산하늘채퍼스트 동편',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3600841840',
#   'routeNo': '남산2',
#   'routeNote': '자안->갈고개->원당->자인',
#   'routeTCd': 'G',
#   'stBsId': '3600041700',
#   'edBsId': '3600041700',
#   'stNm': '자인정류장',
#   'edNm': '자인정류장',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3600841620',
#   'routeNo': '399',
#   'routeNote': '중산하늘채->자인->아사->하양->다문->자인',
#   'routeTCd': 'G',
#   'stBsId': '3600041700',
#   'edBsId': '3600041700',
#   'stNm': '자인정류장',
#   'edNm': '자인정류장',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3600841740',
#   'routeNo': '압량1',
#   'routeNote': '자인->마곡,속초->영남대',
#   'routeTCd': 'G',
#   'stBsId': '3600041700',
#   'edBsId': '7121005800',
#   'stNm': '자인정류장',
#   'edNm': '영남대 건너',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3600841660',
#   'routeNo': '990',
#   'routeNote': '육동->자인->대신동->자인',
#   'routeTCd': 'G',
#   'stBsId': '3600053300',
#   'edBsId': '3600041700',
#   'stNm': '부일리(용성방향)',
#   'edNm': '자인정류장',
#   'dataconnareacd': 'GS'},
#  {'routeId': '4100001025',
#   'routeNo': '팔공1',
#   'routeNote': '동화사(국가정보자원관리원경유, 오후)',
#   'routeTCd': '4',
#   'stBsId': '7021051300',
#   'edBsId': '7011036300',
#   'stNm': '칠성시장',
#   'edNm': '동화사',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4040004006',
#   'routeNo': '달성4',
#   'routeTCd': '4',
#   'stBsId': '7111084700',
#   'edBsId': '7111057000',
#   'stNm': '달성2차산업단지',
#   'edNm': '근린공원축구장건너',
#   'dataconnareacd': 'DG'},
#  {'routeId': '7361101008',
#   'routeNo': '군위1',
#   'routeNote': '군위-도경-광현-용대-상곡-하곡-군위',
#   'routeTCd': '6',
#   'stBsId': '7361000638',
#   'edBsId': '7361000281',
#   'stNm': '군위터미널',
#   'edNm': '군위터미널',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3690003840',
#   'routeNo': '27',
#   'routeNote': '왜관북부정류장_연화_불동_기곡',
#   'routeTCd': 'C',
#   'stBsId': '3690000080',
#   'edBsId': '7111029600',
#   'stNm': '왜관북부',
#   'edNm': '기곡(종점)',
#   'dataconnareacd': 'CG'},
#  {'routeId': '3690003850',
#   'routeNo': '27',
#   'routeNote': '기곡_불동_연화_왜관북부정류장',
#   'routeTCd': 'C',
#   'stBsId': '7111029600',
#   'edBsId': '3690000080',
#   'stNm': '기곡(종점)',
#   'edNm': '왜관북부',
#   'dataconnareacd': 'CG'},
#  {'routeId': '3690004430',
#   'routeNo': '38',
#   'routeNote': '칠곡경대병원_동명_한티재휴게소',
#   'routeTCd': 'C',
#   'stBsId': '7021053200',
#   'edBsId': '3610000350',
#   'stNm': '칠곡경북대병원후문앞',
#   'edNm': '한티재',
#   'dataconnareacd': 'CG'},
#  {'routeId': '3690004370',
#   'routeNo': '38',
#   'routeNote': '한티재휴게소_동명_칠곡경대병원후문',
#   'routeTCd': 'C',
#   'stBsId': '3610000350',
#   'edBsId': '7021053200',
#   'stNm': '한티재',
#   'edNm': '칠곡경북대병원후문앞',
#   'dataconnareacd': 'CG'},
#  {'routeId': '7361102008',
#   'routeNo': '군위2',
#   'routeNote': '군위-오곡-대북-삽령-외량-내량-군위',
#   'routeTCd': '6',
#   'stBsId': '7361000638',
#   'edBsId': '7361000281',
#   'stNm': '군위터미널',
#   'edNm': '군위터미널',
#   'dataconnareacd': 'DG'},
#  {'routeId': '7361102009',
#   'routeNo': '군위2',
#   'routeNote': '군위-효령-화계-달산-봉산-우보-봉산-병수2-오천-군위',
#   'routeTCd': '6',
#   'stBsId': '7361000638',
#   'edBsId': '7361000281',
#   'stNm': '군위터미널',
#   'edNm': '군위터미널',
#   'dataconnareacd': 'DG'},
#  {'routeId': '7361102010',
#   'routeNo': '군위2',
#   'routeNote': '군위-병수2-봉산-우보-달산-화계-효령-군위',
#   'routeTCd': '6',
#   'stBsId': '7361000638',
#   'edBsId': '7361000281',
#   'stNm': '군위터미널',
#   'edNm': '군위터미널',
#   'dataconnareacd': 'DG'},
#  {'routeId': '7361103010',
#   'routeNo': '군위3',
#   'routeNote': '군위-소보-위성1-위성4-보현-복성-소보-군위',
#   'routeTCd': '6',
#   'stBsId': '7361000638',
#   'edBsId': '7361000281',
#   'stNm': '군위터미널',
#   'edNm': '군위터미널',
#   'dataconnareacd': 'DG'},
#  {'routeId': '7361104009',
#   'routeNo': '군위4',
#   'routeNote': '군위-산법-평호-신계-달산-봉황-소보-서경-군위',
#   'routeTCd': '6',
#   'stBsId': '7361000638',
#   'edBsId': '7361000281',
#   'stNm': '군위터미널',
#   'edNm': '군위터미널',
#   'dataconnareacd': 'DG'},
#  {'routeId': '7361105009',
#   'routeNo': '군위5',
#   'routeNote': '군위-불로-내리-효령-구효령-매곡',
#   'routeTCd': '6',
#   'stBsId': '7361000638',
#   'edBsId': '7361000281',
#   'stNm': '군위터미널',
#   'edNm': '군위터미널',
#   'dataconnareacd': 'DG'},
#  {'routeId': '7361106009',
#   'routeNo': '군위6',
#   'routeNote': '군위-노행-효령-장기-효령',
#   'routeTCd': '6',
#   'stBsId': '7361000638',
#   'edBsId': '7361000281',
#   'stNm': '군위터미널',
#   'edNm': '군위터미널',
#   'dataconnareacd': 'DG'},
#  {'routeId': '7361107009',
#   'routeNo': '군위7',
#   'routeNote': '군위-우보-의흥-화수-삼국유사-화수2-신녕',
#   'routeTCd': '6',
#   'stBsId': '7361000638',
#   'edBsId': '7361000281',
#   'stNm': '군위터미널',
#   'edNm': '군위터미널',
#   'dataconnareacd': 'DG'},
#  {'routeId': '7361107010',
#   'routeNo': '군위7',
#   'routeNote': '군위-노행-효령-군위',
#   'routeTCd': '6',
#   'stBsId': '7361000638',
#   'edBsId': '7361000281',
#   'stNm': '군위터미널',
#   'edNm': '군위터미널',
#   'dataconnareacd': 'DG'},
#  {'routeId': '7361108009',
#   'routeNo': '군위8',
#   'routeNote': '군위-수서-효령-명산-부계-둔덕',
#   'routeTCd': '6',
#   'stBsId': '7361000638',
#   'edBsId': '7361000281',
#   'stNm': '군위터미널',
#   'edNm': '군위터미널',
#   'dataconnareacd': 'DG'},
#  {'routeId': '7361109008',
#   'routeNo': '군위9',
#   'routeNote': '군위-우보-탑리-산성-봉림-백학-부계',
#   'routeTCd': '6',
#   'stBsId': '7361000638',
#   'edBsId': '7361000281',
#   'stNm': '군위터미널',
#   'edNm': '군위터미널',
#   'dataconnareacd': 'DG'},
#  {'routeId': '7361110011',
#   'routeNo': '군위10',
#   'routeNote': '낙전-가암2-화수-금양-원산-의흥-우보-군위',
#   'routeTCd': '6',
#   'stBsId': '7361000638',
#   'edBsId': '7361000281',
#   'stNm': '군위터미널',
#   'edNm': '군위터미널',
#   'dataconnareacd': 'DG'},
#  {'routeId': '7361111009',
#   'routeNo': '군위11',
#   'routeNote': '군위-우보-의흥-산성-백학-부계',
#   'routeTCd': '6',
#   'stBsId': '7361000638',
#   'edBsId': '7361000281',
#   'stNm': '군위터미널',
#   'edNm': '군위터미널',
#   'dataconnareacd': 'DG'},
#  {'routeId': '7361110012',
#   'routeNo': '군위10',
#   'routeNote': '낙전-가암2-지호-신덕-의흥-우보-군위',
#   'routeTCd': '6',
#   'stBsId': '7361000638',
#   'edBsId': '7361000281',
#   'stNm': '군위터미널',
#   'edNm': '군위터미널',
#   'dataconnareacd': 'DG'},
#  {'routeId': '7361110013',
#   'routeNo': '군위10',
#   'routeNote': '군위-우보-의흥-신덕-지호-학암-가암2-낙전',
#   'routeTCd': '6',
#   'stBsId': '7361000638',
#   'edBsId': '7361000281',
#   'stNm': '군위터미널',
#   'edNm': '군위터미널',
#   'dataconnareacd': 'DG'},
#  {'routeId': '7361110014',
#   'routeNo': '군위10',
#   'routeNote': '군위-우보-의흥-원산-금양-학암-가암-낙전',
#   'routeTCd': '6',
#   'stBsId': '7361000638',
#   'edBsId': '7361000281',
#   'stNm': '군위터미널',
#   'edNm': '군위터미널',
#   'dataconnareacd': 'DG'},
#  {'routeId': '7361110015',
#   'routeNo': '군위10',
#   'routeNote': '군위-우보-의흥-신덕-지호-학암-낙전',
#   'routeTCd': '6',
#   'stBsId': '7361000638',
#   'edBsId': '7361000281',
#   'stNm': '군위터미널',
#   'edNm': '군위터미널',
#   'dataconnareacd': 'DG'},
#  {'routeId': '7361110016',
#   'routeNo': '군위10',
#   'routeNote': '군위-우보-의흥-학암-낙전',
#   'routeTCd': '6',
#   'stBsId': '7361000638',
#   'edBsId': '7361000281',
#   'stNm': '군위터미널',
#   'edNm': '군위터미널',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3600842770',
#   'routeNo': '555-7',
#   'routeNote': '창신영업소->안심->창신영업소',
#   'routeTCd': 'Y',
#   'stBsId': '357001527 ',
#   'edBsId': '357001527 ',
#   'stNm': '창신영업소',
#   'edNm': '창신영업소',
#   'dataconnareacd': 'YC'},
#  {'routeId': '3600842540',
#   'routeNo': '100-1',
#   'routeNote': '백천->정평->영남대',
#   'routeTCd': 'G',
#   'stBsId': '3600131800',
#   'edBsId': '3600090700',
#   'stNm': '삼도뷰엔빌 종점',
#   'edNm': '영남대 앞',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3600840550',
#   'routeNo': '399',
#   'routeNote': '자인->터미널->경산시장',
#   'routeTCd': 'G',
#   'stBsId': '3600041700',
#   'edBsId': '3600062200',
#   'stNm': '자인정류장',
#   'edNm': '경산시장',
#   'dataconnareacd': 'GS'},
#  {'routeId': '3600842330',
#   'routeNo': '399',
#   'routeNote': '사림->정평역',
#   'routeTCd': 'G',
#   'stBsId': '3600041700',
#   'edBsId': '3600062200',
#   'stNm': '사림종점(남산방향)',
#   'edNm': '중산하늘채퍼스트 서편',
#   'dataconnareacd': 'GS'},
#  {'routeId': '4130002000',
#   'routeNo': '남구2',
#   'routeTCd': '4',
#   'stBsId': '7051014400',
#   'edBsId': '7111069100',
#   'stNm': '앞산공원',
#   'edNm': '방천리',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4060006000',
#   'routeNo': '북구6',
#   'routeTCd': '4',
#   'stBsId': '7021045600',
#   'edBsId': '7021066200',
#   'stNm': '성보교통',
#   'edNm': '성보교통',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4080005000',
#   'routeNo': '수성5',
#   'routeTCd': '4',
#   'stBsId': '7111045900',
#   'edBsId': '7061033500',
#   'stNm': '대일리',
#   'edNm': '두리봉터널',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4030002002',
#   'routeNo': '달서2',
#   'routeTCd': '4',
#   'stBsId': '7041060100',
#   'edBsId': '7051014400',
#   'stNm': '대곡동',
#   'edNm': '앞산공원',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4030006000',
#   'routeNo': '달서6',
#   'routeTCd': '4',
#   'stBsId': '7041060100',
#   'edBsId': '7041060200',
#   'stNm': '대곡동',
#   'edNm': '대곡동',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4100001024',
#   'routeNo': '팔공1',
#   'routeNote': '동화사(국가정보자원관리원경유,오전)',
#   'routeTCd': '4',
#   'stBsId': '7021051300',
#   'edBsId': '7011036300',
#   'stNm': '칠성시장',
#   'edNm': '동화사',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3680000010',
#   'routeNo': '250',
#   'routeNote': '성주_선남_동곡_반고개_새길시장_서문시장_반고개_성주',
#   'routeTCd': 'C',
#   'stBsId': '3680000790',
#   'edBsId': '3680001160',
#   'stNm': '성주터미널',
#   'edNm': '성주터미널',
#   'dataconnareacd': 'CG'},
#  {'routeId': '7361101009',
#   'routeNo': '군위1',
#   'routeNote': '군위-효령-마시1리-교수촌-구효령',
#   'routeTCd': '6',
#   'stBsId': '7361000638',
#   'edBsId': '7361000281',
#   'stNm': '군위터미널',
#   'edNm': '군위터미널',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4040005000',
#   'routeNo': '달성5',
#   'routeNote': '대곡-용연사-유가사',
#   'routeTCd': '4',
#   'stBsId': '7111000100',
#   'edBsId': '7111024400',
#   'stNm': '대곡',
#   'edNm': '유가사',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4050003001',
#   'routeNo': '동구3',
#   'routeNote': '옻골방면',
#   'routeTCd': '4',
#   'stBsId': '7021024100',
#   'edBsId': '7011030300',
#   'stNm': '칠성시장',
#   'edNm': '옻골',
#   'dirRouteNote': '옻골',
#   'ndirRouteNote': '칠성시장',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4050003002',
#   'routeNo': '동구3',
#   'routeNote': 'K2관사방면',
#   'routeTCd': '4',
#   'stBsId': '7021024100',
#   'edBsId': '7011035800',
#   'stNm': '칠성시장',
#   'edNm': 'K2관사',
#   'dirRouteNote': 'K2관사',
#   'ndirRouteNote': '칠성시장',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4050003003',
#   'routeNo': '동구3',
#   'routeNote': '둔산방면',
#   'routeTCd': '4',
#   'stBsId': '7021024100',
#   'edBsId': '7011036100',
#   'stNm': '칠성시장',
#   'edNm': '둔산',
#   'dirRouteNote': '둔산',
#   'ndirRouteNote': '칠성시장',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4060001000',
#   'routeNo': '북구1',
#   'routeTCd': '4',
#   'stBsId': '7021065200',
#   'edBsId': '7021066200',
#   'stNm': '도남동',
#   'edNm': '검단동',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4070001100',
#   'routeNo': '성서1-1',
#   'routeTCd': '4',
#   'stBsId': '7111026900',
#   'edBsId': '7111027000',
#   'stNm': '매곡',
#   'edNm': '매곡',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4070003000',
#   'routeNo': '성서3',
#   'routeNote': '다사-세천-장기-세천-다사',
#   'routeTCd': '4',
#   'stBsId': '7111026900',
#   'edBsId': '7111027000',
#   'stNm': '매곡',
#   'edNm': '매곡',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4080001000',
#   'routeNo': '수성1',
#   'routeTCd': '4',
#   'stBsId': '7061021400',
#   'edBsId': '7061021300',
#   'stNm': '범물동',
#   'edNm': '범물동',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4090003001',
#   'routeNo': '칠곡3',
#   'routeNote': '동명-칠곡시장-동명-예술대-경운대-동명',
#   'routeTCd': '4',
#   'stBsId': '7181007000',
#   'edBsId': '7181007000',
#   'stNm': '동명면',
#   'edNm': '동명면',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000649000',
#   'routeNo': '649',
#   'routeTCd': '3',
#   'stBsId': '7041062100',
#   'edBsId': '7121020700',
#   'stNm': '대곡지구',
#   'edNm': '금구리',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000651000',
#   'routeNo': '651',
#   'routeTCd': '3',
#   'stBsId': '7111018800',
#   'edBsId': '7011037900',
#   'stNm': '명곡지구',
#   'edNm': '반야월역',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000653000',
#   'routeNo': '653',
#   'routeTCd': '3',
#   'stBsId': '7111004500',
#   'edBsId': '7021066200',
#   'stNm': '설화리',
#   'edNm': '검단동(성보교통)',
#   'dataconnareacd': 'DG'},
#  {'routeId': '1000001074',
#   'routeNo': '급행1',
#   'routeNote': '팔공산증회운행(동화사-동대구역)',
#   'routeTCd': '1',
#   'stBsId': '7011025300',
#   'edBsId': '7011036300',
#   'stNm': '동화사',
#   'edNm': '동대구역',
#   'dirRouteNote': '동대구역',
#   'ndirRouteNote': '동화사',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000726000',
#   'routeNo': '726',
#   'routeTCd': '3',
#   'stBsId': '7021062000',
#   'edBsId': '7041020700',
#   'stNm': '동호동',
#   'edNm': '대곡지구',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000805000',
#   'routeNo': '805',
#   'routeTCd': '3',
#   'stBsId': '7041056000',
#   'edBsId': '7011037900',
#   'stNm': '달서아트센터',
#   'edNm': '반야월역',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4010002001',
#   'routeNo': '가창2',
#   'routeNote': '우록방면',
#   'routeTCd': '4',
#   'stBsId': '7021051300',
#   'edBsId': '7021051300',
#   'stNm': '칠성시장',
#   'edNm': '칠성시장',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4010002003',
#   'routeNo': '가창2',
#   'routeNote': '단산(행정)방면',
#   'routeTCd': '4',
#   'stBsId': '7111011000',
#   'edBsId': '7111011000',
#   'stNm': '칠성시장',
#   'edNm': '칠성시장',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4030001000',
#   'routeNo': '달서1',
#   'routeTCd': '4',
#   'stBsId': '7041060400',
#   'edBsId': '7111027000',
#   'stNm': '대천동(공영차고지)',
#   'edNm': '매곡',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000300000',
#   'routeNo': '300',
#   'routeTCd': '3',
#   'stBsId': '7051014400',
#   'edBsId': '7021019800',
#   'stNm': '앞산공원',
#   'edNm': '종합유통단지',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000349000',
#   'routeNo': '349',
#   'routeTCd': '3',
#   'stBsId': '7061059600',
#   'edBsId': '7021047100',
#   'stNm': '시지지구',
#   'edNm': '종합유통단지',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000356000',
#   'routeNo': '356',
#   'routeTCd': '3',
#   'stBsId': '7021029800',
#   'edBsId': '7041032000',
#   'stNm': '조야동',
#   'edNm': '월광수변공원',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000401000',
#   'routeNo': '401',
#   'routeTCd': '3',
#   'stBsId': '7011036000',
#   'edBsId': '7061021300',
#   'stNm': '갓바위',
#   'edNm': '범물동',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000410000',
#   'routeNo': '410',
#   'routeTCd': '3',
#   'stBsId': '7051014400',
#   'edBsId': '7051014400',
#   'stNm': '앞산공원',
#   'edNm': '앞산공원',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000410100',
#   'routeNo': '410-1',
#   'routeTCd': '3',
#   'stBsId': '7051014400',
#   'edBsId': '7051014400',
#   'stNm': '앞산공원',
#   'edNm': '앞산공원',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000527000',
#   'routeNo': '527',
#   'routeTCd': '3',
#   'stBsId': '7111026900',
#   'edBsId': '7181007000',
#   'stNm': '매곡',
#   'edNm': '동명면',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000564000',
#   'routeNo': '564',
#   'routeTCd': '3',
#   'stBsId': '7111026900',
#   'edBsId': '7061021300',
#   'stNm': '매곡',
#   'edNm': '범물동',
#   'dataconnareacd': 'DG'},
#  {'routeId': '1000001000',
#   'routeNo': '급행1',
#   'routeTCd': '1',
#   'stBsId': '7011025300',
#   'edBsId': '7111027000',
#   'stNm': '동화사',
#   'edNm': '매곡',
#   'dataconnareacd': 'DG'},
#  {'routeId': '1000003000',
#   'routeNo': '급행3',
#   'routeTCd': '1',
#   'stBsId': '7061021400',
#   'edBsId': '7181007000',
#   'stNm': '범물동',
#   'edNm': '동명면',
#   'dataconnareacd': 'DG'},
#  {'routeId': '2000002000',
#   'routeNo': '순환2',
#   'routeTCd': '2',
#   'stBsId': '7021045600',
#   'edBsId': '7021066200',
#   'stNm': '검단동',
#   'edNm': '검단동',
#   'dataconnareacd': 'DG'},
#  {'routeId': '2000003000',
#   'routeNo': '순환3',
#   'routeTCd': '2',
#   'stBsId': '7061021400',
#   'edBsId': '7061021300',
#   'stNm': '범물동',
#   'edNm': '범물동',
#   'dataconnareacd': 'DG'},
#  {'routeId': '2000003100',
#   'routeNo': '순환3-1',
#   'routeTCd': '2',
#   'stBsId': '7061021400',
#   'edBsId': '7061021300',
#   'stNm': '범물동',
#   'edNm': '범물동',
#   'dataconnareacd': 'DG'},
#  {'routeId': '3000156000',
#   'routeNo': '156',
#   'routeTCd': '3',
#   'stBsId': '7041054300',
#   'edBsId': '7011055200',
#   'stNm': '성서산업단지',
#   'edNm': '조일고등학교',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4010002118',
#   'routeNo': '가창2',
#   'routeNote': '단산(냉천)방면',
#   'routeTCd': '4',
#   'stBsId': '7021051300',
#   'edBsId': '7021051300',
#   'stNm': '칠성시장',
#   'edNm': '칠성시장',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4040005001',
#   'routeNo': '달성5',
#   'routeNote': '유가사-유곡1-용연사-대곡',
#   'routeTCd': '4',
#   'stBsId': '7111024400',
#   'edBsId': '7041053200',
#   'stNm': '유가사',
#   'edNm': '대곡',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4040005002',
#   'routeNo': '달성5',
#   'routeNote': '유가사-용연사-대곡',
#   'routeTCd': '4',
#   'stBsId': '7111024400',
#   'edBsId': '7041053200',
#   'stNm': '유가사',
#   'edNm': '대곡',
#   'dataconnareacd': 'DG'},
#  {'routeId': '4040005003',
#   'routeNo': '달성5',
#   'routeNote': '대곡-용연사-유곡1-유가사',
#   'routeTCd': '4',
#   'stBsId': '7041053300',
#   'edBsId': '7111024400',
#   'stNm': '대곡',
#   'edNm': '유가사',
#   'dataconnareacd': 'DG'}]

# %% [markdown]
# ---
# ## 🚏 Step 6. 정류장 정보 꺼내기

# %%
# 정류장 데이터
stops = data["body"]["items"]["bs"]

print(f"전체 정류장 수: {len(stops)}개")
print("\n첫 번째 정류장 정보:")
print(json.dumps(stops[0], ensure_ascii=False, indent=2))
# Out:
# 전체 정류장 수: 5913개
#
# 첫 번째 정류장 정보:
# {
#   "bsId": "7041000100",
#   "bsNm": "한국방송통신대학교건너",
#   "xPos": 128.49331521666667,
#   "yPos": 35.859160116666665,
#   "wincId": "01153"
# }

# %% [markdown]
# ### 🎯 미션 2
# 아래 빈칸을 채워서 **"동대구역"** 이 이름에 포함된 정류장을 모두 출력해보세요!

# %%
# 🎯 미션 2: 동대구역 정류장 찾기
keyword = "동대구역"   # ← 원하는 키워드로 바꿔보세요

print(f"'{keyword}' 포함 정류장:")
for stop in stops:
    if keyword in stop["bsNm"]:   # ← 빈칸: 정류장 이름 필드명은?
        print(f"  🚏 {stop['bsNm']} | ID: {stop['bsId']}")
# Out:
# '동대구역' 포함 정류장:
#   🚏 동대구역센트럴시티자이아파트 | ID: 7011003500
#   🚏 동대구역복합환승센터앞 | ID: 7011004000
#   🚏 동대구역복합환승센터건너 | ID: 7011004100
#   🚏 동대구역 | ID: 7011006700
#   🚏 동대구역건너 | ID: 7011006800
#   🚏 동대구역지하도1 | ID: 7011008000
#   🚏 동대구역지하도2 | ID: 7011008100
#   🚏 동대구역수화물취급소건너 | ID: 7011021200
#   🚏 동대구역수화물취급소앞 | ID: 7011021300
#   🚏 동대구역화성파크드림 | ID: 7011006900
#   🚏 동대구역(2번출구)건너 | ID: 7011067300

# %% [markdown]
# ---
# ## 🔗 Step 7. 다른 API 탐색하기
#
# API 문서 페이지에서 다른 API들을 찾아 탐색해봅시다.
#
# ### 📝 탐색 미션 (빈칸 채우기)
#
# | API 이름 | 기능 | 필수 파라미터 | 내가 뽑고 싶은 데이터 |
# |----------|------|--------------|---------------------|
# | getBasic02 | 기초종합 정보 | serviceKey | 노선/정류장 목록 |
# | getBs02 | 노선 ID를 기준으로 경유하는 정류장 정보제공하는 서비스 | serviceKey, routeId | |
# | getLink02 | 노선 ID를 기준으로 경유하는 링크 정보제공하는 서비스 | serviceKey, routeId | |
# | getRealtime02 | 정류소 ID 및 노선 ID를 기준으로 도착예정정보를 제공하는 서비스 | serviceKey, bsId | |
# | getPos02 | 노선 ID를 기준으로 버스 위치 정보제공하는 서비스 | serviceKey, routeId | |

# %%
# 🎯 미션 3: getBs02 - 정류장 상세 정보 조회
# Step 6에서 찾은 정류장 ID를 활용해보세요!

url_bs = "https://apis.data.go.kr/6270000/dbmsapi02/getBs02"

params_bs = {
    "serviceKey": API_KEY,
    "routeId": "3000504000"   # ← Step 6에서 찾은 노선Id(routeId) 입력
}

response_bs = requests.get(url_bs, params=params_bs)
print("응답 코드:", response_bs.status_code)

if response_bs.status_code == 200:
    data_bs = response_bs.json()
    print(json.dumps(data_bs, ensure_ascii=False, indent=2))
# Out:
# 응답 코드: 200
# {
#   "header": {
#     "success": true,
#     "resultCode": "0000",
#     "resultMsg": "성공"
#   },
#   "body": {
#     "items": [
#       {
#         "bsId": "7061059300",
#         "bsNm": "황금고가교네거리",
#         "xPos": 128.64093833333334,
#         "yPos": 35.840675,
#         "moveDir": "0",
#         "seq": "1"
#       },
#       {
#         "bsId": "7061033300",
#         "bsNm": "두리봉터널종점건너",
#         "xPos": 128.64242166666668,
#         "yPos": 35.84367833333334,
#         "moveDir": "0",
#         "seq": "2"
#       },
#       {
#         "bsId": "7061033600",
#         "bsNm": "두리봉터널입구건너",
#         "xPos": 128.64995256666666,
#         "yPos": 35.84641946666667,
#         "moveDir": "0",
#         "seq": "3"
#       },
#       {
#         "bsId": "7061059800",
#         "bsNm": "만촌삼정그린코아건너",
#         "xPos": 128.6529,
#         "yPos": 35.84671,
#         "moveDir": "0",
#         "seq": "4"
#       },
#       {
#         "bsId": "7061024000",
#         "bsNm": "만촌우방1차건너",
#         "xPos": 128.65609436666668,
#         "yPos": 35.84991365,
#         "moveDir": "0",
#         "seq": "5"
#       },
#       {
#         "bsId": "7061023800",
#         "bsNm": "한도아파트앞",
#         "xPos": 128.65405323333334,
#         "yPos": 35.8506375,
#         "moveDir": "0",
#         "seq": "6"
#       },
#       {
#         "bsId": "7061035100",
#         "bsNm": "대청초등학교앞",
#         "xPos": 128.65222,
#         "yPos": 35.85061,
#         "moveDir": "0",
#         "seq": "7"
#       },
#       {
#         "bsId": "7061035200",
#         "bsNm": "소선여중건너",
#         "xPos": 128.65219666666667,
#         "yPos": 35.852153333333334,
#         "moveDir": "0",
#         "seq": "8"
#       },
#       {
#         "bsId": "7061035300",
#         "bsNm": "우방금탑아파트(서편)",
#         "xPos": 128.65270833333332,
#         "yPos": 35.85412,
#         "moveDir": "0",
#         "seq": "9"
#       },
#       {
#         "bsId": "7061022500",
#         "bsNm": "수성대학교건너",
#         "xPos": 128.65138905,
#         "yPos": 35.856369883333336,
#         "moveDir": "0",
#         "seq": "10"
#       },
#       {
#         "bsId": "7061001900",
#         "bsNm": "구.남부정류장앞2",
#         "xPos": 128.6487645,
#         "yPos": 35.85779228333333,
#         "moveDir": "0",
#         "seq": "11"
#       },
#       {
#         "bsId": "7061002000",
#         "bsNm": "만촌육교1",
#         "xPos": 128.64461755,
#         "yPos": 35.8580188,
#         "moveDir": "0",
#         "seq": "12"
#       },
#       {
#         "bsId": "7061002200",
#         "bsNm": "우방청솔맨션건너",
#         "xPos": 128.63931635,
#         "yPos": 35.854643616666664,
#         "moveDir": "0",
#         "seq": "13"
#       },
#       {
#         "bsId": "7061018100",
#         "bsNm": "동도중학교건너",
#         "xPos": 128.63847465,
#         "yPos": 35.849980083333335,
#         "moveDir": "0",
#         "seq": "14"
#       },
#       {
#         "bsId": "7061017900",
#         "bsNm": "국립대구박물관앞",
#         "xPos": 128.63917765,
#         "yPos": 35.847103233333335,
#         "moveDir": "0",
#         "seq": "15"
#       },
#       {
#         "bsId": "7061017700",
#         "bsNm": "경북고등학교건너",
#         "xPos": 128.63875511666666,
#         "yPos": 35.843748383333335,
#         "moveDir": "0",
#         "seq": "16"
#       },
#       {
#         "bsId": "7061017500",
#         "bsNm": "캐슬골드파크4단지앞",
#         "xPos": 128.63655213333334,
#         "yPos": 35.8408138,
#         "moveDir": "0",
#         "seq": "17"
#       },
#       {
#         "bsId": "7061034500",
#         "bsNm": "성동초등학교앞",
#         "xPos": 128.63294461666666,
#         "yPos": 35.84052725,
#         "moveDir": "0",
#         "seq": "18"
#       },
#       {
#         "bsId": "7061017200",
#         "bsNm": "캐슬골드파크(1102동)",
#         "xPos": 128.63085561666668,
#         "yPos": 35.83968051666667,
#         "moveDir": "0",
#         "seq": "19"
#       },
#       {
#         "bsId": "7061017000",
#         "bsNm": "헬로TV대구방송앞",
#         "xPos": 128.62660216666666,
#         "yPos": 35.83934576666667,
#         "moveDir": "0",
#         "seq": "20"
#       },
#       {
#         "bsId": "7061016800",
#         "bsNm": "대구과학고등학교앞",
#         "xPos": 128.62486445,
#         "yPos": 35.84455976666667,
#         "moveDir": "0",
#         "seq": "21"
#       },
#       {
#         "bsId": "7061016200",
#         "bsNm": "어린이세상앞",
#         "xPos": 128.62508941666667,
#         "yPos": 35.84739413333333,
#         "moveDir": "0",
#         "seq": "22"
#       },
#       {
#         "bsId": "7061016300",
#         "bsNm": "대구고용노동청건너",
#         "xPos": 128.6253474,
#         "yPos": 35.850312116666665,
#         "moveDir": "0",
#         "seq": "23"
#       },
#       {
#         "bsId": "7061003900",
#         "bsNm": "범어쌍용예가앞",
#         "xPos": 128.62373545,
#         "yPos": 35.8539103,
#         "moveDir": "0",
#         "seq": "24"
#       },
#       {
#         "bsId": "7061004000",
#         "bsNm": "수성3가롯데캐슬앞",
#         "xPos": 128.62029853333334,
#         "yPos": 35.854144383333335,
#         "moveDir": "0",
#         "seq": "25"
#       },
#       {
#         "bsId": "7061004200",
#         "bsNm": "수성시장네거리2",
#         "xPos": 128.61549176666668,
#         "yPos": 35.85446625,
#         "moveDir": "0",
#         "seq": "26"
#       },
#       {
#         "bsId": "7061004500",
#         "bsNm": "수성롯데캐슬더퍼스트앞",
#         "xPos": 128.61093876666666,
#         "yPos": 35.854764016666664,
#         "moveDir": "0",
#         "seq": "27"
#       },
#       {
#         "bsId": "7001007900",
#         "bsNm": "대백프라자앞",
#         "xPos": 128.60439018333332,
#         "yPos": 35.85521205,
#         "moveDir": "0",
#         "seq": "28"
#       },
#       {
#         "bsId": "7001008000",
#         "bsNm": "대봉성당",
#         "xPos": 128.60072301666668,
#         "yPos": 35.85543885,
#         "moveDir": "0",
#         "seq": "29"
#       },
#       {
#         "bsId": "7001008100",
#         "bsNm": "건들바위건너",
#         "xPos": 128.59855893333332,
#         "yPos": 35.857453066666665,
#         "moveDir": "0",
#         "seq": "30"
#       },
#       {
#         "bsId": "7001008300",
#         "bsNm": "봉산가구골목(동편)",
#         "xPos": 128.59922726666667,
#         "yPos": 35.86151838333333,
#         "moveDir": "0",
#         "seq": "31"
#       },
#       {
#         "bsId": "7001001500",
#         "bsNm": "봉산문화거리건너",
#         "xPos": 128.59693491666667,
#         "yPos": 35.865018166666665,
#         "moveDir": "0",
#         "seq": "32"
#       },
#       {
#         "bsId": "7001013700",
#         "bsNm": "약령시입구",
#         "xPos": 128.58928166666666,
#         "yPos": 35.86638,
#         "moveDir": "0",
#         "seq": "33"
#       },
#       {
#         "bsId": "7001001000",
#         "bsNm": "엘디스리젠트호텔앞",
#         "xPos": 128.58526305,
#         "yPos": 35.865946316666665,
#         "moveDir": "0",
#         "seq": "34"
#       },
#       {
#         "bsId": "7001000800",
#         "bsNm": "청라언덕(신남)역(1번출구)",
#         "xPos": 128.58118338333333,
#         "yPos": 35.864691883333336,
#         "moveDir": "0",
#         "seq": "35"
#       },
#       {
#         "bsId": "7001000700",
#         "bsNm": "대신센트럴자이",
#         "xPos": 128.57800036666666,
#         "yPos": 35.86373531666667,
#         "moveDir": "0",
#         "seq": "36"
#       },
#       {
#         "bsId": "7001000500",
#         "bsNm": "중부소방서건너",
#         "xPos": 128.5755587,
#         "yPos": 35.86312555,
#         "moveDir": "0",
#         "seq": "37"
#       },
#       {
#         "bsId": "7031009200",
#         "bsNm": "반고개1",
#         "xPos": 128.57011833333334,
#         "yPos": 35.861755,
#         "moveDir": "0",
#         "seq": "38"
#       },
#       {
#         "bsId": "7031017000",
#         "bsNm": "반고개(내당역4번출구)",
#         "xPos": 128.56677185,
#         "yPos": 35.860889283333336,
#         "moveDir": "0",
#         "seq": "39"
#       },
#       {
#         "bsId": "7031009100",
#         "bsNm": "현대해상건너",
#         "xPos": 128.5625085,
#         "yPos": 35.859671766666665,
#         "moveDir": "0",
#         "seq": "40"
#       },
#       {
#         "bsId": "7031004400",
#         "bsNm": "두류역(달성고등학교앞)",
#         "xPos": 128.55474946666666,
#         "yPos": 35.857103683333335,
#         "moveDir": "0",
#         "seq": "41"
#       },
#       {
#         "bsId": "7031004100",
#         "bsNm": "감삼네거리1",
#         "xPos": 128.54940931666667,
#         "yPos": 35.854991033333334,
#         "moveDir": "0",
#         "seq": "42"
#       },
#       {
#         "bsId": "7041002200",
#         "bsNm": "서남시장앞1",
#         "xPos": 128.54527753333332,
#         "yPos": 35.85341165,
#         "moveDir": "0",
#         "seq": "43"
#       },
#       {
#         "bsId": "7041008500",
#         "bsNm": "구병원건너",
#         "xPos": 128.542035,
#         "yPos": 35.85221,
#         "moveDir": "0",
#         "seq": "44"
#       },
#       {
#         "bsId": "7041002800",
#         "bsNm": "죽전119안전센터앞",
#         "xPos": 128.53743358333332,
#         "yPos": 35.8523668,
#         "moveDir": "0",
#         "seq": "45"
#       },
#       {
#         "bsId": "7041002600",
#         "bsNm": "죽전동 행정복지센터앞",
#         "xPos": 128.53753253333332,
#         "yPos": 35.85642996666667,
#         "moveDir": "0",
#         "seq": "46"
#       },
#       {
#         "bsId": "7031004000",
#         "bsNm": "용전초등학교남편",
#         "xPos": 128.53290158333334,
#         "yPos": 35.858879216666665,
#         "moveDir": "0",
#         "seq": "47"
#       },
#       {
#         "bsId": "7041003000",
#         "bsNm": "2차서한화성타운앞",
#         "xPos": 128.52872756666667,
#         "yPos": 35.85891325,
#         "moveDir": "0",
#         "seq": "48"
#       },
#       {
#         "bsId": "7041035800",
#         "bsNm": "용산2동행정복지센터건너",
#         "xPos": 128.52302356666667,
#         "yPos": 35.858904683333336,
#         "moveDir": "0",
#         "seq": "49"
#       },
#       {
#         "bsId": "7041055000",
#         "bsNm": "성서주공5단지앞",
#         "xPos": 128.52097263333334,
#         "yPos": 35.85804975,
#         "moveDir": "0",
#         "seq": "50"
#       },
#       {
#         "bsId": "7041051200",
#         "bsNm": "성서청구타운앞",
#         "xPos": 128.52093336666667,
#         "yPos": 35.856281333333335,
#         "moveDir": "0",
#         "seq": "51"
#       },
#       {
#         "bsId": "7041006300",
#         "bsNm": "영남우방타운1차건너",
#         "xPos": 128.51717153333334,
#         "yPos": 35.8552932,
#         "moveDir": "0",
#         "seq": "52"
#       },
#       {
#         "bsId": "7041005700",
#         "bsNm": "조달청건너",
#         "xPos": 128.51444938333333,
#         "yPos": 35.85533855,
#         "moveDir": "0",
#         "seq": "53"
#       },
#       {
#         "bsId": "7041005500",
#         "bsNm": "동서화성타운앞",
#         "xPos": 128.5104938,
#         "yPos": 35.85540666666667,
#         "moveDir": "0",
#         "seq": "54"
#       },
#       {
#         "bsId": "7041005000",
#         "bsNm": "성서우체국건너",
#         "xPos": 128.507028,
#         "yPos": 35.85306885,
#         "moveDir": "0",
#         "seq": "55"
#       },
#       {
#         "bsId": "7041006800",
#         "bsNm": "성서산업단지역(1번출구)",
#         "xPos": 128.50527666666667,
#         "yPos": 35.852113333333335,
#         "moveDir": "0",
#         "seq": "56"
#       },
#       {
#         "bsId": "7041006600",
#         "bsNm": "대백창신한라타운앞",
#         "xPos": 128.50038666666666,
#         "yPos": 35.852085,
#         "moveDir": "0",
#         "seq": "57"
#       },
#       {
#         "bsId": "7041002100",
#         "bsNm": "성서주공1단지앞",
#         "xPos": 128.49606425,
#         "yPos": 35.851733833333334,
#         "moveDir": "0",
#         "seq": "58"
#       },
#       {
#         "bsId": "7041000900",
#         "bsNm": "계명대학교동문건너2",
#         "xPos": 128.49223333333333,
#         "yPos": 35.854218333333336,
#         "moveDir": "0",
#         "seq": "59"
#       },
#       {
#         "bsId": "7041000500",
#         "bsNm": "계명대학교동문건너1",
#         "xPos": 128.49228478333333,
#         "yPos": 35.856631416666666,
#         "moveDir": "0",
#         "seq": "60"
#       },
#       {
#         "bsId": "7041000400",
#         "bsNm": "계명문화대학교건너",
#         "xPos": 128.49232166666667,
#         "yPos": 35.858713333333334,
#         "moveDir": "0",
#         "seq": "61"
#       },
#       {
#         "bsId": "7041038900",
#         "bsNm": "한화꿈에그린건너1",
#         "xPos": 128.49146166666668,
#         "yPos": 35.86488166666667,
#         "moveDir": "0",
#         "seq": "62"
#       },
#       {
#         "bsId": "7111073700",
#         "bsNm": "서재동화아이위시앞",
#         "xPos": 128.49325,
#         "yPos": 35.867895,
#         "moveDir": "0",
#         "seq": "63"
#       },
#       {
#         "bsId": "7111010300",
#         "bsNm": "건영캐스빌앞",
#         "xPos": 128.49552005,
#         "yPos": 35.86878286666666,
#         "moveDir": "0",
#         "seq": "64"
#       },
#       {
#         "bsId": "7111010500",
#         "bsNm": "다사농협주유소건너",
#         "xPos": 128.4967939,
#         "yPos": 35.87095073333333,
#         "moveDir": "0",
#         "seq": "65"
#       },
#       {
#         "bsId": "7111011500",
#         "bsNm": "서재금봉타운",
#         "xPos": 128.49745598333334,
#         "yPos": 35.8738995,
#         "moveDir": "0",
#         "seq": "66"
#       },
#       {
#         "bsId": "7111010800",
#         "bsNm": "서재보성타운앞",
#         "xPos": 128.49676505,
#         "yPos": 35.8766419,
#         "moveDir": "0",
#         "seq": "67"
#       },
#       {
#         "bsId": "7111010900",
#         "bsNm": "성주사앞",
#         "xPos": 128.49872716666667,
#         "yPos": 35.88141885,
#         "moveDir": "0",
#         "seq": "68"
#       },
#       {
#         "bsId": "7111017100",
#         "bsNm": "서재문화체육센터앞1",
#         "xPos": 128.50295666666668,
#         "yPos": 35.884805,
#         "moveDir": "0",
#         "seq": "69"
#       },
#       {
#         "bsId": "7111009700",
#         "bsNm": "방천리1",
#         "xPos": 128.503885,
#         "yPos": 35.88551666666667,
#         "moveDir": "0",
#         "seq": "70"
#       },
#       {
#         "bsId": "7111069100",
#         "bsNm": "방천리공영차고지",
#         "xPos": 128.51001516666668,
#         "yPos": 35.889803433333334,
#         "moveDir": "0",
#         "seq": "71"
#       },
#       {
#         "bsId": "7111069100",
#         "bsNm": "방천리공영차고지",
#         "xPos": 128.51001516666668,
#         "yPos": 35.889803433333334,
#         "moveDir": "1",
#         "seq": "1"
#       },
#       {
#         "bsId": "7111034100",
#         "bsNm": "방천리2",
#         "xPos": 128.50357666666667,
#         "yPos": 35.885508333333334,
#         "moveDir": "1",
#         "seq": "2"
#       },
#       {
#         "bsId": "7111017200",
#         "bsNm": "서재문화체육센터건너",
#         "xPos": 128.50258666666667,
#         "yPos": 35.884813333333334,
#         "moveDir": "1",
#         "seq": "3"
#       },
#       {
#         "bsId": "7111011400",
#         "bsNm": "성주사건너",
#         "xPos": 128.4985363,
#         "yPos": 35.881511683333336,
#         "moveDir": "1",
#         "seq": "4"
#       },
#       {
#         "bsId": "7111010700",
#         "bsNm": "서재보성타운건너",
#         "xPos": 128.496633,
#         "yPos": 35.876687833333335,
#         "moveDir": "1",
#         "seq": "5"
#       },
#       {
#         "bsId": "7111011600",
#         "bsNm": "서재금봉타운건너",
#         "xPos": 128.49721833333334,
#         "yPos": 35.87430666666667,
#         "moveDir": "1",
#         "seq": "6"
#       },
#       {
#         "bsId": "7111010600",
#         "bsNm": "다사농협주유소앞",
#         "xPos": 128.49670511666667,
#         "yPos": 35.871098933333336,
#         "moveDir": "1",
#         "seq": "7"
#       },
#       {
#         "bsId": "7111047500",
#         "bsNm": "건영캐스빌건너",
#         "xPos": 128.49533166666666,
#         "yPos": 35.868838333333336,
#         "moveDir": "1",
#         "seq": "8"
#       },
#       {
#         "bsId": "7111073600",
#         "bsNm": "서재동화아이위시건너",
#         "xPos": 128.4933,
#         "yPos": 35.86806166666667,
#         "moveDir": "1",
#         "seq": "9"
#       },
#       {
#         "bsId": "7041038800",
#         "bsNm": "한화꿈에그린앞",
#         "xPos": 128.49129,
#         "yPos": 35.86353833333333,
#         "moveDir": "1",
#         "seq": "10"
#       },
#       {
#         "bsId": "7041000300",
#         "bsNm": "계명문화대학교앞",
#         "xPos": 128.49182833333333,
#         "yPos": 35.85852,
#         "moveDir": "1",
#         "seq": "11"
#       },
#       {
#         "bsId": "7041000800",
#         "bsNm": "계명대학교동문앞",
#         "xPos": 128.49179453333332,
#         "yPos": 35.854375766666664,
#         "moveDir": "1",
#         "seq": "12"
#       },
#       {
#         "bsId": "7041002000",
#         "bsNm": "성서주공1단지건너",
#         "xPos": 128.49494625,
#         "yPos": 35.851313616666665,
#         "moveDir": "1",
#         "seq": "13"
#       },
#       {
#         "bsId": "7041006500",
#         "bsNm": "대백창신한라타운건너",
#         "xPos": 128.5012809,
#         "yPos": 35.85176516666667,
#         "moveDir": "1",
#         "seq": "14"
#       },
#       {
#         "bsId": "7041005100",
#         "bsNm": "성서우체국앞",
#         "xPos": 128.50743401666668,
#         "yPos": 35.85306236666667,
#         "moveDir": "1",
#         "seq": "15"
#       },
#       {
#         "bsId": "7041060600",
#         "bsNm": "국민연금네거리",
#         "xPos": 128.50892476666667,
#         "yPos": 35.85523791666667,
#         "moveDir": "1",
#         "seq": "16"
#       },
#       {
#         "bsId": "7041005400",
#         "bsNm": "동서화성타운건너",
#         "xPos": 128.51127168333332,
#         "yPos": 35.855195216666665,
#         "moveDir": "1",
#         "seq": "17"
#       },
#       {
#         "bsId": "7041005600",
#         "bsNm": "조달청앞",
#         "xPos": 128.51462593333332,
#         "yPos": 35.855140516666665,
#         "moveDir": "1",
#         "seq": "18"
#       },
#       {
#         "bsId": "7041006200",
#         "bsNm": "영남우방타운1차앞",
#         "xPos": 128.51778248333332,
#         "yPos": 35.85508848333333,
#         "moveDir": "1",
#         "seq": "19"
#       },
#       {
#         "bsId": "7041006400",
#         "bsNm": "성서용산시장앞",
#         "xPos": 128.52115695,
#         "yPos": 35.855753633333336,
#         "moveDir": "1",
#         "seq": "20"
#       },
#       {
#         "bsId": "7041003300",
#         "bsNm": "용산2동행정복지센터앞",
#         "xPos": 128.52204925,
#         "yPos": 35.85865855,
#         "moveDir": "1",
#         "seq": "21"
#       },
#       {
#         "bsId": "7041003100",
#         "bsNm": "2차서한화성타운건너",
#         "xPos": 128.5277578,
#         "yPos": 35.85864168333333,
#         "moveDir": "1",
#         "seq": "22"
#       },
#       {
#         "bsId": "7041002900",
#         "bsNm": "죽전그린빌앞",
#         "xPos": 128.53415943333334,
#         "yPos": 35.85865868333333,
#         "moveDir": "1",
#         "seq": "23"
#       },
#       {
#         "bsId": "7041002500",
#         "bsNm": "죽전동 행정복지센터건너",
#         "xPos": 128.53721648333334,
#         "yPos": 35.857192133333335,
#         "moveDir": "1",
#         "seq": "24"
#       },
#       {
#         "bsId": "7041053900",
#         "bsNm": "죽전119안전센터건너",
#         "xPos": 128.53712913333334,
#         "yPos": 35.85354235,
#         "moveDir": "1",
#         "seq": "25"
#       },
#       {
#         "bsId": "7041008400",
#         "bsNm": "구병원앞",
#         "xPos": 128.5417285,
#         "yPos": 35.851669466666664,
#         "moveDir": "1",
#         "seq": "26"
#       },
#       {
#         "bsId": "7041002300",
#         "bsNm": "서남시장건너",
#         "xPos": 128.54557006666667,
#         "yPos": 35.853143816666666,
#         "moveDir": "1",
#         "seq": "27"
#       },
#       {
#         "bsId": "7041024200",
#         "bsNm": "감삼역(3번출구)",
#         "xPos": 128.54914856666667,
#         "yPos": 35.85451251666667,
#         "moveDir": "1",
#         "seq": "28"
#       },
#       {
#         "bsId": "7031004500",
#         "bsNm": "두류역(달성고등학교건너)",
#         "xPos": 128.5552016,
#         "yPos": 35.85683543333333,
#         "moveDir": "1",
#         "seq": "29"
#       },
#       {
#         "bsId": "7041024700",
#         "bsNm": "현대해상앞",
#         "xPos": 128.56113303333333,
#         "yPos": 35.8588877,
#         "moveDir": "1",
#         "seq": "30"
#       },
#       {
#         "bsId": "7041024800",
#         "bsNm": "반고개2",
#         "xPos": 128.56863188333332,
#         "yPos": 35.86100033333334,
#         "moveDir": "1",
#         "seq": "31"
#       },
#       {
#         "bsId": "7041060300",
#         "bsNm": "반고개역(3번출구)",
#         "xPos": 128.57381666666666,
#         "yPos": 35.86236,
#         "moveDir": "1",
#         "seq": "32"
#       },
#       {
#         "bsId": "7001000600",
#         "bsNm": "중부소방서앞",
#         "xPos": 128.57675568333335,
#         "yPos": 35.863069466666666,
#         "moveDir": "1",
#         "seq": "33"
#       },
#       {
#         "bsId": "7001013800",
#         "bsNm": "청라언덕(신남)역(2번출구)",
#         "xPos": 128.580695,
#         "yPos": 35.864266666666666,
#         "moveDir": "1",
#         "seq": "34"
#       },
#       {
#         "bsId": "7001013900",
#         "bsNm": "청라언덕(신남)역(8번출구)",
#         "xPos": 128.58387333333334,
#         "yPos": 35.86519,
#         "moveDir": "1",
#         "seq": "35"
#       },
#       {
#         "bsId": "7001000900",
#         "bsNm": "엘디스리젠트호텔건너",
#         "xPos": 128.58676073333334,
#         "yPos": 35.86604395,
#         "moveDir": "1",
#         "seq": "36"
#       },
#       {
#         "bsId": "7001001100",
#         "bsNm": "현대백화점.동아쇼핑건너",
#         "xPos": 128.59022248333332,
#         "yPos": 35.86588321666667,
#         "moveDir": "1",
#         "seq": "37"
#       },
#       {
#         "bsId": "7001001300",
#         "bsNm": "봉산문화거리앞",
#         "xPos": 128.59717311666665,
#         "yPos": 35.864635916666664,
#         "moveDir": "1",
#         "seq": "38"
#       },
#       {
#         "bsId": "7001008500",
#         "bsNm": "봉산육거리",
#         "xPos": 128.59923256666667,
#         "yPos": 35.862752883333336,
#         "moveDir": "1",
#         "seq": "39"
#       },
#       {
#         "bsId": "7001008400",
#         "bsNm": "봉산가구골목(서편)",
#         "xPos": 128.59899376666667,
#         "yPos": 35.86123966666667,
#         "moveDir": "1",
#         "seq": "40"
#       },
#       {
#         "bsId": "7001008200",
#         "bsNm": "건들바위앞",
#         "xPos": 128.59850363333334,
#         "yPos": 35.858259266666664,
#         "moveDir": "1",
#         "seq": "41"
#       },
#       {
#         "bsId": "7051009800",
#         "bsNm": "대봉교회",
#         "xPos": 128.6008179,
#         "yPos": 35.85523523333333,
#         "moveDir": "1",
#         "seq": "42"
#       },
#       {
#         "bsId": "7051009500",
#         "bsNm": "대백프라자건너",
#         "xPos": 128.6058352,
#         "yPos": 35.8549233,
#         "moveDir": "1",
#         "seq": "43"
#       },
#       {
#         "bsId": "7061004600",
#         "bsNm": "한가람타운앞",
#         "xPos": 128.61073318333334,
#         "yPos": 35.854503466666664,
#         "moveDir": "1",
#         "seq": "44"
#       },
#       {
#         "bsId": "7061004300",
#         "bsNm": "수성시장네거리1",
#         "xPos": 128.61596775,
#         "yPos": 35.8542672,
#         "moveDir": "1",
#         "seq": "45"
#       },
#       {
#         "bsId": "7061004100",
#         "bsNm": "수성3가롯데캐슬건너",
#         "xPos": 128.62003471666668,
#         "yPos": 35.853968783333336,
#         "moveDir": "1",
#         "seq": "46"
#       },
#       {
#         "bsId": "7061000300",
#         "bsNm": "범어쌍용예가건너(호텔라온제나)",
#         "xPos": 128.62263388333332,
#         "yPos": 35.8538013,
#         "moveDir": "1",
#         "seq": "47"
#       },
#       {
#         "bsId": "7061040800",
#         "bsNm": "수성구민운동장건너",
#         "xPos": 128.62498333333335,
#         "yPos": 35.85274,
#         "moveDir": "1",
#         "seq": "48"
#       },
#       {
#         "bsId": "7061016500",
#         "bsNm": "대구고용노동청앞",
#         "xPos": 128.62462573333335,
#         "yPos": 35.84914188333333,
#         "moveDir": "1",
#         "seq": "49"
#       },
#       {
#         "bsId": "7061016600",
#         "bsNm": "어린이세상건너1",
#         "xPos": 128.62445265,
#         "yPos": 35.847434883333335,
#         "moveDir": "1",
#         "seq": "50"
#       },
#       {
#         "bsId": "7061016700",
#         "bsNm": "대구과학고등학교건너",
#         "xPos": 128.62419336666667,
#         "yPos": 35.8442881,
#         "moveDir": "1",
#         "seq": "51"
#       },
#       {
#         "bsId": "7061016900",
#         "bsNm": "헬로TV대구방송건너",
#         "xPos": 128.62599283333333,
#         "yPos": 35.839212483333334,
#         "moveDir": "1",
#         "seq": "52"
#       },
#       {
#         "bsId": "7061017100",
#         "bsNm": "캐슬골드파크(1504동)",
#         "xPos": 128.63064318333332,
#         "yPos": 35.83934745,
#         "moveDir": "1",
#         "seq": "53"
#       },
#       {
#         "bsId": "7061017300",
#         "bsNm": "성동초등학교건너",
#         "xPos": 128.63330033333332,
#         "yPos": 35.84037885,
#         "moveDir": "1",
#         "seq": "54"
#       },
#       {
#         "bsId": "7061017400",
#         "bsNm": "황금힐스테이트",
#         "xPos": 128.63697418333334,
#         "yPos": 35.84048653333333,
#         "moveDir": "1",
#         "seq": "55"
#       },
#       {
#         "bsId": "7061017600",
#         "bsNm": "경북고등학교앞",
#         "xPos": 128.63904281666666,
#         "yPos": 35.8437715,
#         "moveDir": "1",
#         "seq": "56"
#       },
#       {
#         "bsId": "7061017800",
#         "bsNm": "국립대구박물관건너",
#         "xPos": 128.63932771666666,
#         "yPos": 35.846657783333335,
#         "moveDir": "1",
#         "seq": "57"
#       },
#       {
#         "bsId": "7061018000",
#         "bsNm": "동도중학교앞",
#         "xPos": 128.63880961666666,
#         "yPos": 35.849211016666665,
#         "moveDir": "1",
#         "seq": "58"
#       },
#       {
#         "bsId": "7061002300",
#         "bsNm": "우방청솔맨션앞",
#         "xPos": 128.6402936,
#         "yPos": 35.85519516666667,
#         "moveDir": "1",
#         "seq": "59"
#       },
#       {
#         "bsId": "7061002100",
#         "bsNm": "만촌육교2",
#         "xPos": 128.64505498333332,
#         "yPos": 35.85790838333333,
#         "moveDir": "1",
#         "seq": "60"
#       },
#       {
#         "bsId": "7061028700",
#         "bsNm": "구.남부정류장건너2",
#         "xPos": 128.64855841666667,
#         "yPos": 35.857496966666666,
#         "moveDir": "1",
#         "seq": "61"
#       },
#       {
#         "bsId": "7061022400",
#         "bsNm": "수성대학교앞",
#         "xPos": 128.65009651666668,
#         "yPos": 35.856664783333336,
#         "moveDir": "1",
#         "seq": "62"
#       },
#       {
#         "bsId": "7061023600",
#         "bsNm": "만촌3차화성파크드림건너",
#         "xPos": 128.65215923333332,
#         "yPos": 35.85357618333333,
#         "moveDir": "1",
#         "seq": "63"
#       },
#       {
#         "bsId": "7061058000",
#         "bsNm": "소선여중앞",
#         "xPos": 128.65200833333333,
#         "yPos": 35.85217333333333,
#         "moveDir": "1",
#         "seq": "64"
#       },
#       {
#         "bsId": "7061023700",
#         "bsNm": "대청초등학교건너",
#         "xPos": 128.65239881666668,
#         "yPos": 35.850472133333334,
#         "moveDir": "1",
#         "seq": "65"
#       },
#       {
#         "bsId": "7061023900",
#         "bsNm": "만촌우방1차앞",
#         "xPos": 128.65508045,
#         "yPos": 35.85022073333333,
#         "moveDir": "1",
#         "seq": "66"
#       },
#       {
#         "bsId": "7061035000",
#         "bsNm": "우방아파트삼거리",
#         "xPos": 128.65670371666667,
#         "yPos": 35.84956761666667,
#         "moveDir": "1",
#         "seq": "67"
#       },
#       {
#         "bsId": "7061059700",
#         "bsNm": "만촌삼정그린코아앞",
#         "xPos": 128.65290333333334,
#         "yPos": 35.84693,
#         "moveDir": "1",
#         "seq": "68"
#       },
#       {
#         "bsId": "7061033700",
#         "bsNm": "두리봉터널입구",
#         "xPos": 128.64899205,
#         "yPos": 35.84705401666667,
#         "moveDir": "1",
#         "seq": "69"
#       },
#       {
#         "bsId": "7061033500",
#         "bsNm": "두리봉터널종점",
#         "xPos": 128.64200666666667,
#         "yPos": 35.844766666666665,
#         "moveDir": "1",
#         "seq": "70"
#       }
#     ],
#     "totalCount": 141
#   }
# }

# %% [markdown]
# ---
# ## 🏆 Step 8. 나만의 탐색 코드 작성
#
# 지금까지 배운 것을 활용해서 **내가 원하는 정보를 조회하는 코드**를 작성해보세요!
#
# **아이디어 예시:**
# - 집 근처 정류장 찾기
# - 특정 번호 버스의 출발지/도착지 확인
# - 정류장 이름에 '학교'가 들어가는 곳 찾기

# %%
# 🏆 나만의 탐색 코드
# 아이디어: ___________________________

# 여기에 코드를 작성하세요!

# %% [markdown]
# ---
# ## 📚 정리
#
# 오늘 배운 것:
#
# | 개념 | 코드 | 설명 |
# |------|------|------|
# | API 요청 | `requests.get(url, params=params)` | 서버에 데이터 요청 |
# | 응답 확인 | `response.status_code` | 200이면 성공 |
# | JSON 변환 | `response.json()` | 딕셔너리로 변환 |
# | 데이터 접근 | `data["body"]["items"]` | 키로 접근 |
# | 데이터 탐색 | `for item in items:` | 반복문으로 탐색 |
# | 조건 필터 | `if "키워드" in item["필드"]:` | 원하는 것만 추출 |
